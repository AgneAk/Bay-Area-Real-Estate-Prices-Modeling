# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# **Type of data selected:** <br>Data from Zillow, listed properties <br>Real Estate Trend Data in Bay Area<br> Home Affordability Index Data <br> Unemployment Data <br> Crime Rate Data <br> School Rating Data <br>

# %%
# load all the data

zillow_data = pd.read_csv('/Users/baytech11/Desktop/Agnes/Springboard/Capstone Project/prepared data/SFdata')

trends_data = pd.read_csv('/Users/baytech11/Desktop/Agnes/Springboard/Capstone Project/prepared data/trends_data')

HAI_data = pd.read_csv('/Users/baytech11/Desktop/Agnes/Springboard/Capstone Project/prepared data/HAI_data')

unemployment_data = pd.read_csv('/Users/baytech11/Desktop/Agnes/Springboard/Capstone Project/prepared data/unemployment_data')

crime_data = pd.read_csv('/Users/baytech11/Desktop/Agnes/Springboard/Capstone Project/prepared data/crime_data')

school_data = pd.read_csv('/Users/baytech11/Desktop/Agnes/Springboard/Capstone Project/prepared data/school_ratings')

# %%
zillow_data.head(3)
# Out:
#     propertyType  lotAreaValue                                     address  \
# 0  SINGLE_FAMILY      3001.284      1723 11th Ave, San Francisco, CA 94122
# 1  SINGLE_FAMILY      3125.000      170 Thrift St, San Francisco, CA 94112
# 2  SINGLE_FAMILY      2495.988  1631 La Salle Ave, San Francisco, CA 94124
#
#     price  bedrooms  longitude  latitude      zpid  bathrooms  livingArea  \
# 0  995000       2.0 -122.46822  37.75599  15111551        1.0      1038.0
# 1  898000       4.0 -122.45815  37.71772  15192217        2.0      1845.0
# 2  995000       4.0 -122.38945  37.73663  15156010        4.0      2430.0
#
#   newConstructionType  listingSubType.is_newHome           city  price_per_sqf
# 0               False                      False  San Francisco          959.0
# 1               False                      False  San Francisco          487.0
# 2               False                      False  San Francisco          409.0

# %%
zillow_data.head()
# Out:
#     propertyType  lotAreaValue                                     address  \
# 0  SINGLE_FAMILY      3001.284      1723 11th Ave, San Francisco, CA 94122
# 1  SINGLE_FAMILY      3125.000      170 Thrift St, San Francisco, CA 94112
# 2  SINGLE_FAMILY      2495.988  1631 La Salle Ave, San Francisco, CA 94124
# 3  SINGLE_FAMILY      3036.132     411 Clipper St, San Francisco, CA 94114
# 4  SINGLE_FAMILY      1746.756      1710 33rd Ave, San Francisco, CA 94122
#
#     price  bedrooms  longitude   latitude      zpid  bathrooms  livingArea  \
# 0  995000       2.0 -122.46822  37.755990  15111551        1.0      1038.0
# 1  898000       4.0 -122.45815  37.717720  15192217        2.0      1845.0
# 2  995000       4.0 -122.38945  37.736630  15156010        4.0      2430.0
# 3  998000       3.0 -122.43447  37.748610  15181544        1.0      1470.0
# 4  988000       2.0 -122.49134  37.755177  15110735        1.0      1025.0
#
#   newConstructionType  listingSubType.is_newHome           city  price_per_sqf
# 0               False                      False  San Francisco          959.0
# 1               False                      False  San Francisco          487.0
# 2               False                      False  San Francisco          409.0
# 3               False                      False  San Francisco          679.0
# 4               False                      False  San Francisco          964.0

# %%
#adding county names

conditions =[(zillow_data['city'] == 'San Francisco'),
    ((zillow_data['city'] =="San Mateo")| (zillow_data['city'] =="Redwood City")| (zillow_data['city'] =="Palo Alto")),
    ((zillow_data['city'] =="Mountain View") | (zillow_data['city'] =="Sunnyvale") |(zillow_data['city'] =="Santa Clara") | (zillow_data['city'] =="Los Gatos") |(zillow_data['city'] =="San Jose")|(zillow_data['city'] =="Milpitas")),
    ((zillow_data['city'] =="Fremont")|(zillow_data['city'] =="Pleasanton")|(zillow_data['city'] =="Livermore")|(zillow_data['city'] =="Dublin") |(zillow_data['city'] =="Castro Valley")|(zillow_data['city'] =="Piedmont")|(zillow_data['city'] =="Alameda")|(zillow_data['city'] =="Berkeley")),
    ((zillow_data['city'] =="San Ramon")|(zillow_data['city'] =="Lafayette")|(zillow_data['city'] =="Martinez")|(zillow_data['city'] =="Brentwood")),
    (zillow_data['city'] =="Benicia"),
    (zillow_data['city'] =="Larkspur")]
     
     
counties = ['San Francisco', 'San Mateo', 'Santa Clara', 'Alameda', 'Contra Costa', 'Solano', 'Marin']
     
zillow_data['county'] = np.select(conditions, counties)
     
zillow_data.head()
# Out:
#     propertyType  lotAreaValue                                     address  \
# 0  SINGLE_FAMILY      3001.284      1723 11th Ave, San Francisco, CA 94122
# 1  SINGLE_FAMILY      3125.000      170 Thrift St, San Francisco, CA 94112
# 2  SINGLE_FAMILY      2495.988  1631 La Salle Ave, San Francisco, CA 94124
# 3  SINGLE_FAMILY      3036.132     411 Clipper St, San Francisco, CA 94114
# 4  SINGLE_FAMILY      1746.756      1710 33rd Ave, San Francisco, CA 94122
#
#     price  bedrooms  longitude   latitude      zpid  bathrooms  livingArea  \
# 0  995000       2.0 -122.46822  37.755990  15111551        1.0      1038.0
# 1  898000       4.0 -122.45815  37.717720  15192217        2.0      1845.0
# 2  995000       4.0 -122.38945  37.736630  15156010        4.0      2430.0
# 3  998000       3.0 -122.43447  37.748610  15181544        1.0      1470.0
# 4  988000       2.0 -122.49134  37.755177  15110735        1.0      1025.0
#
#   newConstructionType  listingSubType.is_newHome           city  \
# 0               False                      False  San Francisco
# 1               False                      False  San Francisco
# 2               False                      False  San Francisco
# 3               False                      False  San Francisco
# 4               False                      False  San Francisco
#
#    price_per_sqf         county
# 0          959.0  San Francisco
# 1          487.0  San Francisco
# 2          409.0  San Francisco
# 3          679.0  San Francisco
# 4          964.0  San Francisco

# %%
zillow_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2176 entries, 0 to 2175
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   propertyType               2176 non-null   object
#  1   lotAreaValue               2176 non-null   float64
#  2   address                    2176 non-null   object
#  3   price                      2176 non-null   int64
#  4   bedrooms                   2176 non-null   float64
#  5   longitude                  2176 non-null   float64
#  6   latitude                   2176 non-null   float64
#  7   zpid                       2176 non-null   int64
#  8   bathrooms                  2176 non-null   float64
#  9   livingArea                 2176 non-null   float64
#  10  newConstructionType        2176 non-null   object
#  11  listingSubType.is_newHome  2176 non-null   bool
#  12  city                       2176 non-null   object
#  13  price_per_sqf              2176 non-null   float64
#  14  county                     2176 non-null   object
# dtypes: bool(1), float64(7), int64(2), object(5)
# memory usage: 240.2+ KB

# %%
#selecting property type and price per sqf columns for calculations
#selecting city and county columns for data merge

zillow_data = zillow_data.drop(['address', 'zpid'], axis=1)

# %%
zillow_data.head(3)
# Out:
#     propertyType  lotAreaValue   price  bedrooms  longitude  latitude  \
# 0  SINGLE_FAMILY      3001.284  995000       2.0 -122.46822  37.75599
# 1  SINGLE_FAMILY      3125.000  898000       4.0 -122.45815  37.71772
# 2  SINGLE_FAMILY      2495.988  995000       4.0 -122.38945  37.73663
#
#    bathrooms  livingArea newConstructionType  listingSubType.is_newHome  \
# 0        1.0      1038.0               False                      False
# 1        2.0      1845.0               False                      False
# 2        4.0      2430.0               False                      False
#
#             city  price_per_sqf         county
# 0  San Francisco          959.0  San Francisco
# 1  San Francisco          487.0  San Francisco
# 2  San Francisco          409.0  San Francisco

# %%
trends_data.head(3)
# Out:
#              Location        Year  Median price  Growth (%)
# 0    Marin County, CA  2020-05-01     1262500.0       -0.39
# 1   San Francisco, CA  2020-05-01     1472500.0        3.30
# 2  Alameda County, CA  2020-05-01      859500.0       -0.06

# %%
#renaming Location column to county column

trends_data.rename(columns = {'Location':'county'}, inplace = True)

# %%
#removing words County,CA from names

trends_data['county'] = trends_data['county'].str.replace('County, CA', '')
trends_data['county'] = trends_data['county'].str.replace(', CA', '')

# %%
trends_data
# Out:
#            county        Year  Median price  Growth (%)
# 0          Marin   2020-05-01     1262500.0       -0.39
# 1   San Francisco  2020-05-01     1472500.0        3.30
# 2        Alameda   2020-05-01      859500.0       -0.06
# 3         Solano   2020-05-01      470000.0        6.80
# 4      San Mateo   2020-05-01     1537500.0       -0.81
# 5   Contra Costa   2020-05-01      640000.0       -0.78
# 6    Santa Clara   2020-05-01     1230000.0        1.70
# 7        Alameda   2020-10-01      909500.0        8.30
# 8      San Mateo   2020-10-01     1450000.0        7.30
# 9   San Francisco  2020-10-01     1400000.0       -3.90
# 10        Solano   2020-10-01      485000.0        7.80
# 11         Marin   2020-10-01     1375000.0       10.00
# 12  Contra Costa   2020-10-01      725000.0       13.30
# 13   Santa Clara   2020-10-01     1270000.0       15.50
# 14  San Francisco  2021-05-01     1450000.0       -1.50
# 15         Marin   2021-05-01     1450000.0       14.90
# 16        Solano   2021-05-01      550750.0       17.20
# 17  Contra Costa   2021-05-01      867000.0       35.30
# 18     San Mateo   2021-05-01     1650000.0        7.30
# 19   Santa Clara   2021-05-01     1400000.0       13.80
# 20       Alameda   2021-05-01     1100000.0       28.00
# 21         Marin   2021-10-01     1435000.0        4.40
# 22  Contra Costa   2021-10-01      820000.0       13.10
# 23     San Mateo   2021-10-01     1620000.0       11.70
# 24   Santa Clara   2021-10-01     1400000.0       10.20
# 25       Alameda   2021-10-01     1070000.0       17.60
# 26  San Francisco  2021-10-01     1525000.0        8.90
# 27        Solano   2021-10-01      560000.0       15.50
# 28  San Francisco  2022-05-01     1505000.0        3.80
# 29       Alameda   2022-05-01     1270000.0       15.50
# 30   Santa Clara   2022-05-01     1600000.0       14.30
# 31  Contra Costa   2022-05-01      900000.0        3.80
# 32        Solano   2022-05-01      606000.0       10.00
# 33         Marin   2022-05-01     1650000.0       13.80
# 34     San Mateo   2022-05-01     1717500.0        4.10
# 35         Marin   2022-10-01     1530000.0        6.60
# 36        Solano   2022-10-01      569000.0        1.60
# 37  Contra Costa   2022-10-01      794000.0       -3.20
# 38     San Mateo   2022-10-01     1529000.0       -5.60
# 39   Santa Clara   2022-10-01     1385000.0       -1.10
# 40       Alameda   2022-10-01     1070000.0        0.00
# 41  San Francisco  2022-10-01     1422500.0       -6.70

# %%
#selecting only most recent data

trends_data = trends_data.loc[trends_data['Year'].isin(['2022-10-01'])]

# %%
trends_data.reset_index(inplace=True)

# %%
#dropping Year column

trends_data = trends_data.drop(columns=['Year','index'], axis=1)

# %%
trends_data
# Out:
#           county  Median price  Growth (%)
# 0         Marin      1530000.0         6.6
# 1        Solano       569000.0         1.6
# 2  Contra Costa       794000.0        -3.2
# 3     San Mateo      1529000.0        -5.6
# 4   Santa Clara      1385000.0        -1.1
# 5       Alameda      1070000.0         0.0
# 6  San Francisco     1422500.0        -6.7

# %% [markdown]
# # Merging zillow and trends data frames

# %%
zillow_data['county'].unique()
# Out:
# array(['San Francisco', 'San Mateo', 'Santa Clara', 'Alameda',
#        'Contra Costa', 'Solano', 'Marin'], dtype=object)

# %%
trends_data['county'].unique()
# Out:
# array(['Marin ', 'Solano ', 'Contra Costa ', 'San Mateo ', 'Santa Clara ',
#        'Alameda ', 'San Francisco'], dtype=object)

# %%
trends_data['county'] = trends_data['county'].str.replace('Marin ', 'Marin')
trends_data['county'] = trends_data['county'].str.replace('Solano ', 'Solano')
trends_data['county'] = trends_data['county'].str.replace('Contra Costa ', 'Contra Costa')
trends_data['county'] = trends_data['county'].str.replace('San Mateo ', 'San Mateo')
trends_data['county'] = trends_data['county'].str.replace('Santa Clara ', 'Santa Clara')
trends_data['county'] = trends_data['county'].str.replace('Alameda ', 'Alameda')

# %%
df1 = pd.merge(zillow_data, trends_data, on='county', how='left')

# %%
df1
# Out:
#        propertyType  lotAreaValue    price  bedrooms   longitude   latitude  \
# 0     SINGLE_FAMILY     3001.2840   995000       2.0 -122.468220  37.755990
# 1     SINGLE_FAMILY     3125.0000   898000       4.0 -122.458150  37.717720
# 2     SINGLE_FAMILY     2495.9880   995000       4.0 -122.389450  37.736630
# 3     SINGLE_FAMILY     3036.1320   998000       3.0 -122.434470  37.748610
# 4     SINGLE_FAMILY     1746.7560   988000       2.0 -122.491340  37.755177
# ...             ...           ...      ...       ...         ...        ...
# 2171  SINGLE_FAMILY     8001.9720  2495000       3.0 -122.526060  37.939000
# 2172  SINGLE_FAMILY        0.2812  1995000       4.0 -122.552390  37.932980
# 2173  SINGLE_FAMILY     5528.0000  1845000       2.0 -122.539505  37.932587
# 2174          CONDO      719.0000   489000       1.0 -122.534860  37.940845
# 2175  SINGLE_FAMILY     9801.0000  2795000       3.0 -122.536980  37.925392
#
#       bathrooms  livingArea newConstructionType  listingSubType.is_newHome  \
# 0           1.0      1038.0               False                      False
# 1           2.0      1845.0               False                      False
# 2           4.0      2430.0               False                      False
# 3           1.0      1470.0               False                      False
# 4           1.0      1025.0               False                      False
# ...         ...         ...                 ...                        ...
# 2171        2.0      1725.0               False                      False
# 2172        3.0      2156.0               False                      False
# 2173        2.0      1550.0               False                      False
# 2174        1.0       706.0               False                      False
# 2175        3.0      2160.0               False                      False
#
#                city  price_per_sqf         county  Median price  Growth (%)
# 0     San Francisco          959.0  San Francisco     1422500.0        -6.7
# 1     San Francisco          487.0  San Francisco     1422500.0        -6.7
# 2     San Francisco          409.0  San Francisco     1422500.0        -6.7
# 3     San Francisco          679.0  San Francisco     1422500.0        -6.7
# 4     San Francisco          964.0  San Francisco     1422500.0        -6.7
# ...             ...            ...            ...           ...         ...
# 2171       Larkspur         1446.0          Marin     1530000.0         6.6
# 2172       Larkspur          925.0          Marin     1530000.0         6.6
# 2173       Larkspur         1190.0          Marin     1530000.0         6.6
# 2174       Larkspur          693.0          Marin     1530000.0         6.6
# 2175       Larkspur         1294.0          Marin     1530000.0         6.6
#
# [2176 rows x 15 columns]

# %%
df1.isna().sum()
# Out:
# propertyType                 0
# lotAreaValue                 0
# price                        0
# bedrooms                     0
# longitude                    0
# latitude                     0
# bathrooms                    0
# livingArea                   0
# newConstructionType          0
# listingSubType.is_newHome    0
# city                         0
# price_per_sqf                0
# county                       0
# Median price                 0
# Growth (%)                   0
# dtype: int64

# %% [markdown]
# # Merging with HAI data

# %%
HAI_data.head(3)
# Out:
#   STATE/REGION/COUNTY  Q32022  Q22022  Q32021  Median Home Price  \
# 0       CA SFH (SAAR)      36      34      42             705300
# 1  CA Condo/Townhomes      48      46      55             535500
# 2       S.F. Bay Area      33      28      37            1075250
#
#    Monthly Payment Including Taxes & Insurance  Minimum Qualifying Income
# 0                                         4050                     121500
# 1                                         3070                      92100
# 2                                         6170                     185100

# %%
HAI_data.rename(columns = {'STATE/REGION/COUNTY':'county'},inplace=True)

# %%
HAI_data
# Out:
#                 county  Q32022  Q22022  Q32021  Median Home Price  \
# 0        CA SFH (SAAR)      36      34      42             705300
# 1   CA Condo/Townhomes      48      46      55             535500
# 2        S.F. Bay Area      33      28      37            1075250
# 3                   US      59      58      66             338730
# 4              Alameda      31      25      35            1071000
# 5         Contra Costa      45      41      50             753310
# 6                Marin      25      24      32            1445000
# 7                 Napa      28      33      42             935000
# 8        San Francisco      28      25      29            1411000
# 9            San Mateo      27      24      26            1641350
# 10         Santa Clara      28      26      33            1434800
# 11              Solano      54      54      62             505750
# 12              Sonoma      39      38      48             701250
#
#     Monthly Payment Including Taxes & Insurance  Minimum Qualifying Income
# 0                                          4050                     121500
# 1                                          3070                      92100
# 2                                          6170                     185100
# 3                                          1940                      58200
# 4                                          6150                     184500
# 5                                          4320                     129600
# 6                                          8290                     248700
# 7                                          5370                     161100
# 8                                          8100                     243000
# 9                                          9420                     282600
# 10                                         8230                     246900
# 11                                         2900                      87000
# 12                                         4020                     120600

# %%
#removing first four rows which does not represent county

HAI_data.drop(index=HAI_data.index[:4],inplace=True)

# %%
HAI_data
# Out:
#            county  Q32022  Q22022  Q32021  Median Home Price  \
# 4         Alameda      31      25      35            1071000
# 5    Contra Costa      45      41      50             753310
# 6           Marin      25      24      32            1445000
# 7            Napa      28      33      42             935000
# 8   San Francisco      28      25      29            1411000
# 9       San Mateo      27      24      26            1641350
# 10    Santa Clara      28      26      33            1434800
# 11         Solano      54      54      62             505750
# 12         Sonoma      39      38      48             701250
#
#     Monthly Payment Including Taxes & Insurance  Minimum Qualifying Income
# 4                                          6150                     184500
# 5                                          4320                     129600
# 6                                          8290                     248700
# 7                                          5370                     161100
# 8                                          8100                     243000
# 9                                          9420                     282600
# 10                                         8230                     246900
# 11                                         2900                      87000
# 12                                         4020                     120600

# %%
df2 = pd.merge(df1, HAI_data, on='county', how='left')

# %%
df2
# Out:
#        propertyType  lotAreaValue    price  bedrooms   longitude   latitude  \
# 0     SINGLE_FAMILY     3001.2840   995000       2.0 -122.468220  37.755990
# 1     SINGLE_FAMILY     3125.0000   898000       4.0 -122.458150  37.717720
# 2     SINGLE_FAMILY     2495.9880   995000       4.0 -122.389450  37.736630
# 3     SINGLE_FAMILY     3036.1320   998000       3.0 -122.434470  37.748610
# 4     SINGLE_FAMILY     1746.7560   988000       2.0 -122.491340  37.755177
# ...             ...           ...      ...       ...         ...        ...
# 2171  SINGLE_FAMILY     8001.9720  2495000       3.0 -122.526060  37.939000
# 2172  SINGLE_FAMILY        0.2812  1995000       4.0 -122.552390  37.932980
# 2173  SINGLE_FAMILY     5528.0000  1845000       2.0 -122.539505  37.932587
# 2174          CONDO      719.0000   489000       1.0 -122.534860  37.940845
# 2175  SINGLE_FAMILY     9801.0000  2795000       3.0 -122.536980  37.925392
#
#       bathrooms  livingArea newConstructionType  listingSubType.is_newHome  \
# 0           1.0      1038.0               False                      False
# 1           2.0      1845.0               False                      False
# 2           4.0      2430.0               False                      False
# 3           1.0      1470.0               False                      False
# 4           1.0      1025.0               False                      False
# ...         ...         ...                 ...                        ...
# 2171        2.0      1725.0               False                      False
# 2172        3.0      2156.0               False                      False
# 2173        2.0      1550.0               False                      False
# 2174        1.0       706.0               False                      False
# 2175        3.0      2160.0               False                      False
#
#       ... price_per_sqf         county Median price  Growth (%)  Q32022  \
# 0     ...         959.0  San Francisco    1422500.0        -6.7      28
# 1     ...         487.0  San Francisco    1422500.0        -6.7      28
# 2     ...         409.0  San Francisco    1422500.0        -6.7      28
# 3     ...         679.0  San Francisco    1422500.0        -6.7      28
# 4     ...         964.0  San Francisco    1422500.0        -6.7      28
# ...   ...           ...            ...          ...         ...     ...
# 2171  ...        1446.0          Marin    1530000.0         6.6      25
# 2172  ...         925.0          Marin    1530000.0         6.6      25
# 2173  ...        1190.0          Marin    1530000.0         6.6      25
# 2174  ...         693.0          Marin    1530000.0         6.6      25
# 2175  ...        1294.0          Marin    1530000.0         6.6      25
#
#       Q22022  Q32021  Median Home Price  \
# 0         25      29            1411000
# 1         25      29            1411000
# 2         25      29            1411000
# 3         25      29            1411000
# 4         25      29            1411000
# ...      ...     ...                ...
# 2171      24      32            1445000
# 2172      24      32            1445000
# 2173      24      32            1445000
# 2174      24      32            1445000
# 2175      24      32            1445000
#
#       Monthly Payment Including Taxes & Insurance  Minimum Qualifying Income
# 0                                            8100                     243000
# 1                                            8100                     243000
# 2                                            8100                     243000
# 3                                            8100                     243000
# 4                                            8100                     243000
# ...                                           ...                        ...
# 2171                                         8290                     248700
# 2172                                         8290                     248700
# 2173                                         8290                     248700
# 2174                                         8290                     248700
# 2175                                         8290                     248700
#
# [2176 rows x 21 columns]

# %%
#checking if merge was successful and there are no nan values

df2.isna().sum()
# Out:
# propertyType                                   0
# lotAreaValue                                   0
# price                                          0
# bedrooms                                       0
# longitude                                      0
# latitude                                       0
# bathrooms                                      0
# livingArea                                     0
# newConstructionType                            0
# listingSubType.is_newHome                      0
# city                                           0
# price_per_sqf                                  0
# county                                         0
# Median price                                   0
# Growth (%)                                     0
# Q32022                                         0
# Q22022                                         0
# Q32021                                         0
# Median Home Price                              0
# Monthly Payment Including Taxes & Insurance    0
# Minimum Qualifying Income                      0
# dtype: int64

# %% [markdown]
# # Merging with Unemployment Data

# %%
unemployment_data.head(3)
# Out:
#          County  avg_rate
# 0       Alameda      3.15
# 1  Contra Costa      3.41
# 2         Marin      2.34

# %%
#changing column county name to lower case

unemployment_data.columns= unemployment_data.columns.str.lower()

# %%
unemployment_data.head(3)
# Out:
#          county  avg_rate
# 0       Alameda      3.15
# 1  Contra Costa      3.41
# 2         Marin      2.34

# %%
unemployment_data['county'].unique()
# Out:
# array(['Alameda', 'Contra Costa', 'Marin', 'Napa', 'San Francisco',
#        'San Mateo', 'Santa Clara', 'Solano County', 'Sonoma County'],
#       dtype=object)

# %%
unemployment_data['county'] = unemployment_data['county'].str.replace('Solano County', 'Solano')
unemployment_data['county'] = unemployment_data['county'].str.replace('Sonoma County', 'Sonoma')

# %%
df3 = pd.merge(df2, unemployment_data, on='county', how='left')

# %%
df3
# Out:
#        propertyType  lotAreaValue    price  bedrooms   longitude   latitude  \
# 0     SINGLE_FAMILY     3001.2840   995000       2.0 -122.468220  37.755990
# 1     SINGLE_FAMILY     3125.0000   898000       4.0 -122.458150  37.717720
# 2     SINGLE_FAMILY     2495.9880   995000       4.0 -122.389450  37.736630
# 3     SINGLE_FAMILY     3036.1320   998000       3.0 -122.434470  37.748610
# 4     SINGLE_FAMILY     1746.7560   988000       2.0 -122.491340  37.755177
# ...             ...           ...      ...       ...         ...        ...
# 2171  SINGLE_FAMILY     8001.9720  2495000       3.0 -122.526060  37.939000
# 2172  SINGLE_FAMILY        0.2812  1995000       4.0 -122.552390  37.932980
# 2173  SINGLE_FAMILY     5528.0000  1845000       2.0 -122.539505  37.932587
# 2174          CONDO      719.0000   489000       1.0 -122.534860  37.940845
# 2175  SINGLE_FAMILY     9801.0000  2795000       3.0 -122.536980  37.925392
#
#       bathrooms  livingArea newConstructionType  listingSubType.is_newHome  \
# 0           1.0      1038.0               False                      False
# 1           2.0      1845.0               False                      False
# 2           4.0      2430.0               False                      False
# 3           1.0      1470.0               False                      False
# 4           1.0      1025.0               False                      False
# ...         ...         ...                 ...                        ...
# 2171        2.0      1725.0               False                      False
# 2172        3.0      2156.0               False                      False
# 2173        2.0      1550.0               False                      False
# 2174        1.0       706.0               False                      False
# 2175        3.0      2160.0               False                      False
#
#       ...         county  Median price Growth (%)  Q32022  Q22022  Q32021  \
# 0     ...  San Francisco     1422500.0       -6.7      28      25      29
# 1     ...  San Francisco     1422500.0       -6.7      28      25      29
# 2     ...  San Francisco     1422500.0       -6.7      28      25      29
# 3     ...  San Francisco     1422500.0       -6.7      28      25      29
# 4     ...  San Francisco     1422500.0       -6.7      28      25      29
# ...   ...            ...           ...        ...     ...     ...     ...
# 2171  ...          Marin     1530000.0        6.6      25      24      32
# 2172  ...          Marin     1530000.0        6.6      25      24      32
# 2173  ...          Marin     1530000.0        6.6      25      24      32
# 2174  ...          Marin     1530000.0        6.6      25      24      32
# 2175  ...          Marin     1530000.0        6.6      25      24      32
#
#       Median Home Price  Monthly Payment Including Taxes & Insurance  \
# 0               1411000                                         8100
# 1               1411000                                         8100
# 2               1411000                                         8100
# 3               1411000                                         8100
# 4               1411000                                         8100
# ...                 ...                                          ...
# 2171            1445000                                         8290
# 2172            1445000                                         8290
# 2173            1445000                                         8290
# 2174            1445000                                         8290
# 2175            1445000                                         8290
#
#       Minimum Qualifying Income  avg_rate
# 0                        243000      2.39
# 1                        243000      2.39
# 2                        243000      2.39
# 3                        243000      2.39
# 4                        243000      2.39
# ...                         ...       ...
# 2171                     248700      2.34
# 2172                     248700      2.34
# 2173                     248700      2.34
# 2174                     248700      2.34
# 2175                     248700      2.34
#
# [2176 rows x 22 columns]

# %%
#checking if merge was successful and there are no nan values

df3.isna().sum()
# Out:
# propertyType                                   0
# lotAreaValue                                   0
# price                                          0
# bedrooms                                       0
# longitude                                      0
# latitude                                       0
# bathrooms                                      0
# livingArea                                     0
# newConstructionType                            0
# listingSubType.is_newHome                      0
# city                                           0
# price_per_sqf                                  0
# county                                         0
# Median price                                   0
# Growth (%)                                     0
# Q32022                                         0
# Q22022                                         0
# Q32021                                         0
# Median Home Price                              0
# Monthly Payment Including Taxes & Insurance    0
# Minimum Qualifying Income                      0
# avg_rate                                       0
# dtype: int64

# %% [markdown]
# # Merging with Crime data

# %%
crime_data.head(3)
# Out:
#    index California Cities  Population  Violent crime  Property crime  \
# 0      3     San Francisco      886007           5933           48780
# 1      9          Berkeley      122788            618            6256
# 2     38       Santa Clara      131173            214            4748
#
#    Burglary  Total Crimes per 1000  Violent Crimes per 1000  \
# 0      4644                  66.99                     6.70
# 1       771                  62.26                     5.03
# 2       363                  40.60                     1.63
#
#    Property Crimes per 1000  Burglary Crimes per 1000  Crime Rate per Day
# 0                     55.06                      5.24              162.62
# 1                     50.95                      6.28               20.95
# 2                     36.20                      2.77               14.59

# %%
#changing 'California Cities' to 'city'
crime_data.rename(columns={'California Cities':'city'}, inplace=True)

# %%
#leaving columns city, population, and crime values per 1000ppl:
crime_data = crime_data.drop(columns=['index', 'Violent crime', 'Property crime', 'Burglary', 'Crime Rate per Day'])
crime_data
# Out:
#              city  Population  Total Crimes per 1000  Violent Crimes per 1000  \
# 0   San Francisco      886007                  66.99                     6.70
# 1        Berkeley      122788                  62.26                     5.03
# 2     Santa Clara      131173                  40.60                     1.63
# 3         Alameda       78907                  37.50                     2.05
# 4   Mountain View       84599                  34.86                     1.95
# 5       Palo Alto       66938                  33.58                     1.28
# 6        San Jose     1040008                  32.54                     4.38
# 7        Milpitas       82344                  30.31                     1.24
# 8       San Mateo      106020                  28.29                     2.51
# 9       Sunnyvale      154859                  26.46                     1.67
# 10      Brentwood       65483                  25.09                     2.54
# 11        Fremont      240887                  22.71                     1.66
# 12     Pleasanton       84017                  22.53                     1.33
# 13         Dublin       66072                  22.40                     1.62
# 14      Livermore       91418                  20.63                     2.11
# 15       Martinez       38692                  19.44                     2.15
# 16        Benicia       28471                  16.33                     0.56
# 17      Los Gatos       30793                  15.91                     0.45
# 18      Lafayette       26872                  15.03                     0.15
#
#     Property Crimes per 1000  Burglary Crimes per 1000
# 0                      55.06                      5.24
# 1                      50.95                      6.28
# 2                      36.20                      2.77
# 3                      32.68                      2.76
# 4                      29.11                      3.79
# 5                      29.62                      2.67
# 6                      24.20                      3.96
# 7                      26.63                      2.44
# 8                      20.91                      4.87
# 9                      21.83                      2.96
# 10                     20.39                      2.17
# 11                     18.78                      2.27
# 12                     19.42                      1.77
# 13                     19.06                      1.73
# 14                     17.00                      1.52
# 15                     14.73                      2.56
# 16                     13.24                      2.53
# 17                     13.61                      1.85
# 18                     13.32                      1.56

# %%
crime_data['city'].unique()
# Out:
# array(['San Francisco', 'Berkeley', 'Santa Clara', 'Alameda',
#        'Mountain View', 'Palo Alto', 'San Jose', 'Milpitas', 'San Mateo',
#        'Sunnyvale', 'Brentwood', 'Fremont', 'Pleasanton', 'Dublin',
#        'Livermore', 'Martinez', 'Benicia', 'Los Gatos', 'Lafayette'],
#       dtype=object)

# %%
crime_data.city.nunique()
# Out:
# 19

# %%
df3['city'].unique()
# Out:
# array(['San Francisco', 'San Mateo', 'Redwood City', 'Palo Alto',
#        'Mountain View', 'Sunnyvale', 'Santa Clara', 'Los Gatos',
#        'San Jose', 'Milpitas', 'Fremont', 'Pleasanton', 'Livermore',
#        'Dublin', 'Castro Valley', 'San Ramon', 'Alameda', 'Piedmont',
#        'Berkeley', 'Lafayette', 'Martinez', 'Benicia', 'Brentwood',
#        'Larkspur'], dtype=object)

# %%
df3.city.nunique()
# Out:
# 24

# %%
#there are 5 cities crime data missing. For the best results, collecting crime data from https://www.neighborhoodscout.com/
missing = { 
            'city':['Redwood City', 'Castro Valley', 'San Ramon', 'Piedmont', 'Larkspur'],
            'Population':[84292, 66441, 84605, 11270, 13064],
            'Total Crimes per 1000':[20.06, 13.27, 10.80, 35.14, 22.58],
            'Violent Crimes per 1000':[2.23, 2.41, 0.67, 1.77, 1.15],
            'Property Crimes per 1000':[17.83, 10.87, 10.13, 33.36, 21.43],
            'Burglary Crimes per 1000':[2.86, 3.12, 1.24, 5.86, 5.43]
}


missing_df = pd.DataFrame(missing)
display(missing_df)
# Out:
#             city  Population  Total Crimes per 1000  Violent Crimes per 1000  \
# 0   Redwood City       84292                  20.06                     2.23
# 1  Castro Valley       66441                  13.27                     2.41
# 2      San Ramon       84605                  10.80                     0.67
# 3       Piedmont       11270                  35.14                     1.77
# 4       Larkspur       13064                  22.58                     1.15
#
#    Property Crimes per 1000  Burglary Crimes per 1000
# 0                     17.83                      2.86
# 1                     10.87                      3.12
# 2                     10.13                      1.24
# 3                     33.36                      5.86
# 4                     21.43                      5.43

# %%
crime_data = pd.concat([crime_data, missing_df])

# %%
crime_data
# Out:
#              city  Population  Total Crimes per 1000  Violent Crimes per 1000  \
# 0   San Francisco      886007                  66.99                     6.70
# 1        Berkeley      122788                  62.26                     5.03
# 2     Santa Clara      131173                  40.60                     1.63
# 3         Alameda       78907                  37.50                     2.05
# 4   Mountain View       84599                  34.86                     1.95
# 5       Palo Alto       66938                  33.58                     1.28
# 6        San Jose     1040008                  32.54                     4.38
# 7        Milpitas       82344                  30.31                     1.24
# 8       San Mateo      106020                  28.29                     2.51
# 9       Sunnyvale      154859                  26.46                     1.67
# 10      Brentwood       65483                  25.09                     2.54
# 11        Fremont      240887                  22.71                     1.66
# 12     Pleasanton       84017                  22.53                     1.33
# 13         Dublin       66072                  22.40                     1.62
# 14      Livermore       91418                  20.63                     2.11
# 15       Martinez       38692                  19.44                     2.15
# 16        Benicia       28471                  16.33                     0.56
# 17      Los Gatos       30793                  15.91                     0.45
# 18      Lafayette       26872                  15.03                     0.15
# 0    Redwood City       84292                  20.06                     2.23
# 1   Castro Valley       66441                  13.27                     2.41
# 2       San Ramon       84605                  10.80                     0.67
# 3        Piedmont       11270                  35.14                     1.77
# 4        Larkspur       13064                  22.58                     1.15
#
#     Property Crimes per 1000  Burglary Crimes per 1000
# 0                      55.06                      5.24
# 1                      50.95                      6.28
# 2                      36.20                      2.77
# 3                      32.68                      2.76
# 4                      29.11                      3.79
# 5                      29.62                      2.67
# 6                      24.20                      3.96
# 7                      26.63                      2.44
# 8                      20.91                      4.87
# 9                      21.83                      2.96
# 10                     20.39                      2.17
# 11                     18.78                      2.27
# 12                     19.42                      1.77
# 13                     19.06                      1.73
# 14                     17.00                      1.52
# 15                     14.73                      2.56
# 16                     13.24                      2.53
# 17                     13.61                      1.85
# 18                     13.32                      1.56
# 0                      17.83                      2.86
# 1                      10.87                      3.12
# 2                      10.13                      1.24
# 3                      33.36                      5.86
# 4                      21.43                      5.43

# %%
#merging
df4 = pd.merge(df3, crime_data, on='city', how='left')

# %%
df4
# Out:
#        propertyType  lotAreaValue    price  bedrooms   longitude   latitude  \
# 0     SINGLE_FAMILY     3001.2840   995000       2.0 -122.468220  37.755990
# 1     SINGLE_FAMILY     3125.0000   898000       4.0 -122.458150  37.717720
# 2     SINGLE_FAMILY     2495.9880   995000       4.0 -122.389450  37.736630
# 3     SINGLE_FAMILY     3036.1320   998000       3.0 -122.434470  37.748610
# 4     SINGLE_FAMILY     1746.7560   988000       2.0 -122.491340  37.755177
# ...             ...           ...      ...       ...         ...        ...
# 2171  SINGLE_FAMILY     8001.9720  2495000       3.0 -122.526060  37.939000
# 2172  SINGLE_FAMILY        0.2812  1995000       4.0 -122.552390  37.932980
# 2173  SINGLE_FAMILY     5528.0000  1845000       2.0 -122.539505  37.932587
# 2174          CONDO      719.0000   489000       1.0 -122.534860  37.940845
# 2175  SINGLE_FAMILY     9801.0000  2795000       3.0 -122.536980  37.925392
#
#       bathrooms  livingArea newConstructionType  listingSubType.is_newHome  \
# 0           1.0      1038.0               False                      False
# 1           2.0      1845.0               False                      False
# 2           4.0      2430.0               False                      False
# 3           1.0      1470.0               False                      False
# 4           1.0      1025.0               False                      False
# ...         ...         ...                 ...                        ...
# 2171        2.0      1725.0               False                      False
# 2172        3.0      2156.0               False                      False
# 2173        2.0      1550.0               False                      False
# 2174        1.0       706.0               False                      False
# 2175        3.0      2160.0               False                      False
#
#       ... Q32021  Median Home Price  \
# 0     ...     29            1411000
# 1     ...     29            1411000
# 2     ...     29            1411000
# 3     ...     29            1411000
# 4     ...     29            1411000
# ...   ...    ...                ...
# 2171  ...     32            1445000
# 2172  ...     32            1445000
# 2173  ...     32            1445000
# 2174  ...     32            1445000
# 2175  ...     32            1445000
#
#      Monthly Payment Including Taxes & Insurance  Minimum Qualifying Income  \
# 0                                           8100                     243000
# 1                                           8100                     243000
# 2                                           8100                     243000
# 3                                           8100                     243000
# 4                                           8100                     243000
# ...                                          ...                        ...
# 2171                                        8290                     248700
# 2172                                        8290                     248700
# 2173                                        8290                     248700
# 2174                                        8290                     248700
# 2175                                        8290                     248700
#
#       avg_rate  Population  Total Crimes per 1000  Violent Crimes per 1000  \
# 0         2.39      886007                  66.99                     6.70
# 1         2.39      886007                  66.99                     6.70
# 2         2.39      886007                  66.99                     6.70
# 3         2.39      886007                  66.99                     6.70
# 4         2.39      886007                  66.99                     6.70
# ...        ...         ...                    ...                      ...
# 2171      2.34       13064                  22.58                     1.15
# 2172      2.34       13064                  22.58                     1.15
# 2173      2.34       13064                  22.58                     1.15
# 2174      2.34       13064                  22.58                     1.15
# 2175      2.34       13064                  22.58                     1.15
#
#       Property Crimes per 1000  Burglary Crimes per 1000
# 0                        55.06                      5.24
# 1                        55.06                      5.24
# 2                        55.06                      5.24
# 3                        55.06                      5.24
# 4                        55.06                      5.24
# ...                        ...                       ...
# 2171                     21.43                      5.43
# 2172                     21.43                      5.43
# 2173                     21.43                      5.43
# 2174                     21.43                      5.43
# 2175                     21.43                      5.43
#
# [2176 rows x 27 columns]

# %%
df4.isna().sum()
# Out:
# propertyType                                   0
# lotAreaValue                                   0
# price                                          0
# bedrooms                                       0
# longitude                                      0
# latitude                                       0
# bathrooms                                      0
# livingArea                                     0
# newConstructionType                            0
# listingSubType.is_newHome                      0
# city                                           0
# price_per_sqf                                  0
# county                                         0
# Median price                                   0
# Growth (%)                                     0
# Q32022                                         0
# Q22022                                         0
# Q32021                                         0
# Median Home Price                              0
# Monthly Payment Including Taxes & Insurance    0
# Minimum Qualifying Income                      0
# avg_rate                                       0
# Population                                     0
# Total Crimes per 1000                          0
# Violent Crimes per 1000                        0
# Property Crimes per 1000                       0
# Burglary Crimes per 1000                       0
# dtype: int64

# %% [markdown]
# # Merging on Schools data

# %%
school_data.head(3)
# Out:
#         District   City or Town         County Rating
# 0      Tamalpais       Larkspur          Marin     A+
# 1  San Francisco  San Francisco  San Francisco     A-
# 2      San Mateo      San Mateo      San Mateo     A+

# %%
#changing 'City or Town' to 'city'
school_data.rename(columns={'City or Town':'city'}, inplace=True)

# %%
school_data['city'].unique()
# Out:
# array(['Larkspur', 'San Francisco', 'San Mateo', 'Redwood', 'Palo Alto',
#        'Mountain View', 'Sunnyvale', 'Santa Clara', 'Los Gatos',
#        'San Jose', 'Milpitas', 'Fremont', 'Pleasanton', 'Livermore',
#        'Dublin', 'Castro Valley', 'Alameda', 'Piedmont', 'Berkeley',
#        'Lafayette', 'Martinez', 'Benicia', 'Brentwood', 'San Ramon'],
#       dtype=object)

# %%
#changing "Redwood" to 'Redwood City'
school_data['city'] = school_data['city'].str.replace('Redwood', 'Redwood City')

# %%
data = pd.merge(df4, school_data, on='city', how='left')

# %%
data
# Out:
#        propertyType  lotAreaValue    price  bedrooms   longitude   latitude  \
# 0     SINGLE_FAMILY     3001.2840   995000       2.0 -122.468220  37.755990
# 1     SINGLE_FAMILY     3125.0000   898000       4.0 -122.458150  37.717720
# 2     SINGLE_FAMILY     2495.9880   995000       4.0 -122.389450  37.736630
# 3     SINGLE_FAMILY     3036.1320   998000       3.0 -122.434470  37.748610
# 4     SINGLE_FAMILY     1746.7560   988000       2.0 -122.491340  37.755177
# ...             ...           ...      ...       ...         ...        ...
# 2171  SINGLE_FAMILY     8001.9720  2495000       3.0 -122.526060  37.939000
# 2172  SINGLE_FAMILY        0.2812  1995000       4.0 -122.552390  37.932980
# 2173  SINGLE_FAMILY     5528.0000  1845000       2.0 -122.539505  37.932587
# 2174          CONDO      719.0000   489000       1.0 -122.534860  37.940845
# 2175  SINGLE_FAMILY     9801.0000  2795000       3.0 -122.536980  37.925392
#
#       bathrooms  livingArea newConstructionType  listingSubType.is_newHome  \
# 0           1.0      1038.0               False                      False
# 1           2.0      1845.0               False                      False
# 2           4.0      2430.0               False                      False
# 3           1.0      1470.0               False                      False
# 4           1.0      1025.0               False                      False
# ...         ...         ...                 ...                        ...
# 2171        2.0      1725.0               False                      False
# 2172        3.0      2156.0               False                      False
# 2173        2.0      1550.0               False                      False
# 2174        1.0       706.0               False                      False
# 2175        3.0      2160.0               False                      False
#
#       ... Minimum Qualifying Income  avg_rate Population  \
# 0     ...                    243000      2.39     886007
# 1     ...                    243000      2.39     886007
# 2     ...                    243000      2.39     886007
# 3     ...                    243000      2.39     886007
# 4     ...                    243000      2.39     886007
# ...   ...                       ...       ...        ...
# 2171  ...                    248700      2.34      13064
# 2172  ...                    248700      2.34      13064
# 2173  ...                    248700      2.34      13064
# 2174  ...                    248700      2.34      13064
# 2175  ...                    248700      2.34      13064
#
#       Total Crimes per 1000  Violent Crimes per 1000  \
# 0                     66.99                     6.70
# 1                     66.99                     6.70
# 2                     66.99                     6.70
# 3                     66.99                     6.70
# 4                     66.99                     6.70
# ...                     ...                      ...
# 2171                  22.58                     1.15
# 2172                  22.58                     1.15
# 2173                  22.58                     1.15
# 2174                  22.58                     1.15
# 2175                  22.58                     1.15
#
#       Property Crimes per 1000  Burglary Crimes per 1000       District  \
# 0                        55.06                      5.24  San Francisco
# 1                        55.06                      5.24  San Francisco
# 2                        55.06                      5.24  San Francisco
# 3                        55.06                      5.24  San Francisco
# 4                        55.06                      5.24  San Francisco
# ...                        ...                       ...            ...
# 2171                     21.43                      5.43      Tamalpais
# 2172                     21.43                      5.43      Tamalpais
# 2173                     21.43                      5.43      Tamalpais
# 2174                     21.43                      5.43      Tamalpais
# 2175                     21.43                      5.43      Tamalpais
#
#              County  Rating
# 0     San Francisco      A-
# 1     San Francisco      A-
# 2     San Francisco      A-
# 3     San Francisco      A-
# 4     San Francisco      A-
# ...             ...     ...
# 2171          Marin      A+
# 2172          Marin      A+
# 2173          Marin      A+
# 2174          Marin      A+
# 2175          Marin      A+
#
# [2176 rows x 30 columns]

# %%
data.isna().sum()
# Out:
# propertyType                                   0
# lotAreaValue                                   0
# price                                          0
# bedrooms                                       0
# longitude                                      0
# latitude                                       0
# bathrooms                                      0
# livingArea                                     0
# newConstructionType                            0
# listingSubType.is_newHome                      0
# city                                           0
# price_per_sqf                                  0
# county                                         0
# Median price                                   0
# Growth (%)                                     0
# Q32022                                         0
# Q22022                                         0
# Q32021                                         0
# Median Home Price                              0
# Monthly Payment Including Taxes & Insurance    0
# Minimum Qualifying Income                      0
# avg_rate                                       0
# Population                                     0
# Total Crimes per 1000                          0
# Violent Crimes per 1000                        0
# Property Crimes per 1000                       0
# Burglary Crimes per 1000                       0
# District                                       0
# County                                         0
# Rating                                         0
# dtype: int64

# %%
for col in data.columns:
    print(col)
# Out:
# propertyType
# lotAreaValue
# price
# bedrooms
# longitude
# latitude
# bathrooms
# livingArea
# newConstructionType
# listingSubType.is_newHome
# city
# price_per_sqf
# county
# Median price
# Growth (%)
# Q32022
# Q22022
# Q32021
# Median Home Price
# Monthly Payment Including Taxes & Insurance
# Minimum Qualifying Income
# avg_rate
# Population
# Total Crimes per 1000
# Violent Crimes per 1000
# Property Crimes per 1000
# Burglary Crimes per 1000
# District
# County
# Rating

# %%
#removing unnecessary columns from data

data = data.drop(columns=['Q32022', 'Q22022', 'Q32021', 'District', 'County'])

# %%
#changing column names

dict = {'propertyType':'Property Type',
'lotAreaValue': 'Lot Area (sqf)',
'price': "Property Price ($)",
'bedrooms': 'Number of Bedrooms',
'bathrooms':'Number of Bathrooms',
'livingArea':'Living Area (sqf)',
'newConstructionType':'Construction Type',
'listingSubType.is_newHome':'Listing Type',
'city':'City',
'county':'County',
'price_per_sqf': 'Price per sqf ($)',
'Median price':'Median RE Price in the Area',
'Growth (%)':'Median Price Growth (%) in the Area',
'Median Home Price':'Median Home Price',
'Monthly Payment Including Taxes & Insurance':'Monthly Payment (($)[Tax&Ins])',
'Minimum Qualifying Income':'Minimum Qualifying Income ($)',
'avg_rate': 'Unemployment Rate (%)',
'Population':'City Population',
'Rating':'School Rating'}

data.rename(columns=dict,
          inplace=True)

# %%
data.head()
# Out:
#    Property Type  Lot Area (sqf)  Property Price ($)  Number of Bedrooms  \
# 0  SINGLE_FAMILY        3001.284              995000                 2.0
# 1  SINGLE_FAMILY        3125.000              898000                 4.0
# 2  SINGLE_FAMILY        2495.988              995000                 4.0
# 3  SINGLE_FAMILY        3036.132              998000                 3.0
# 4  SINGLE_FAMILY        1746.756              988000                 2.0
#
#    longitude   latitude  Number of Bathrooms  Living Area (sqf)  \
# 0 -122.46822  37.755990                  1.0             1038.0
# 1 -122.45815  37.717720                  2.0             1845.0
# 2 -122.38945  37.736630                  4.0             2430.0
# 3 -122.43447  37.748610                  1.0             1470.0
# 4 -122.49134  37.755177                  1.0             1025.0
#
#   Construction Type  Listing Type  ... Median Home Price  \
# 0             False         False  ...           1411000
# 1             False         False  ...           1411000
# 2             False         False  ...           1411000
# 3             False         False  ...           1411000
# 4             False         False  ...           1411000
#
#    Monthly Payment (($)[Tax&Ins]) Minimum Qualifying Income ($)  \
# 0                            8100                        243000
# 1                            8100                        243000
# 2                            8100                        243000
# 3                            8100                        243000
# 4                            8100                        243000
#
#    Unemployment Rate (%)  City Population  Total Crimes per 1000  \
# 0                   2.39           886007                  66.99
# 1                   2.39           886007                  66.99
# 2                   2.39           886007                  66.99
# 3                   2.39           886007                  66.99
# 4                   2.39           886007                  66.99
#
#    Violent Crimes per 1000  Property Crimes per 1000  \
# 0                      6.7                     55.06
# 1                      6.7                     55.06
# 2                      6.7                     55.06
# 3                      6.7                     55.06
# 4                      6.7                     55.06
#
#    Burglary Crimes per 1000  School Rating
# 0                      5.24             A-
# 1                      5.24             A-
# 2                      5.24             A-
# 3                      5.24             A-
# 4                      5.24             A-
#
# [5 rows x 25 columns]

# %%
#checking numerical and categorical values

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2176 entries, 0 to 2175
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Property Type                        2176 non-null   object
#  1   Lot Area (sqf)                       2176 non-null   float64
#  2   Property Price ($)                   2176 non-null   int64
#  3   Number of Bedrooms                   2176 non-null   float64
#  4   longitude                            2176 non-null   float64
#  5   latitude                             2176 non-null   float64
#  6   Number of Bathrooms                  2176 non-null   float64
#  7   Living Area (sqf)                    2176 non-null   float64
#  8   Construction Type                    2176 non-null   object
#  9   Listing Type                         2176 non-null   bool
#  10  City                                 2176 non-null   object
#  11  Price per sqf ($)                    2176 non-null   float64
#  12  County                               2176 non-null   object
#  13  Median RE Price in the Area          2176 non-null   float64
#  14  Median Price Growth (%) in the Area  2176 non-null   float64
#  15  Median Home Price                    2176 non-null   int64
#  16  Monthly Payment (($)[Tax&Ins])       2176 non-null   int64
#  17  Minimum Qualifying Income ($)        2176 non-null   int64
#  18  Unemployment Rate (%)                2176 non-null   float64
#  19  City Population                      2176 non-null   int64
#  20  Total Crimes per 1000                2176 non-null   float64
#  21  Violent Crimes per 1000              2176 non-null   float64
#  22  Property Crimes per 1000             2176 non-null   float64
#  23  Burglary Crimes per 1000             2176 non-null   float64
#  24  School Rating                        2176 non-null   object
# dtypes: bool(1), float64(14), int64(5), object(5)
# memory usage: 427.1+ KB

# %%
#Plotting correlation between features

plt.figure(figsize=(20,20))
_ = sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# **Data has multiple values of price:** <br> Property Price($) <br> Price per sqf <br> Median RE Price in the Area (county wide)<br> Median Home Price (City Wide)<br> To avoid data leaking removing all, except Price per sqf. Although Median Home Price has higher correlation with other features than Price per sqf, this data was collected from HAI data frame with it's calculations and can show false correlation in our data.

# %%
data1 = data.drop(columns=['Property Price ($)','Median Home Price', 'Median RE Price in the Area'], axis=1)

# %% [markdown]
# # Getting Dummies

# %%
final_data = pd.get_dummies(data1, columns=['Property Type', 'School Rating', 'City', 'Construction Type', 
                                        'Listing Type', 'County' ], drop_first=False)

# %%
final_data.corr()
# Out:
#                                                Lot Area (sqf)  \
# Lot Area (sqf)                                       1.000000
# Number of Bedrooms                                   0.266084
# longitude                                            0.088158
# latitude                                             0.015417
# Number of Bathrooms                                  0.005852
# Living Area (sqf)                                    0.139062
# Price per sqf ($)                                    0.108241
# Median Price Growth (%) in the Area                  0.076748
# Monthly Payment (($)[Tax&Ins])                      -0.060453
# Minimum Qualifying Income ($)                       -0.060453
# Unemployment Rate (%)                                0.061790
# City Population                                     -0.011951
# Total Crimes per 1000                               -0.049776
# Violent Crimes per 1000                             -0.024105
# Property Crimes per 1000                            -0.049808
# Burglary Crimes per 1000                            -0.053176
# Property Type_CONDO                                 -0.314323
# Property Type_SINGLE_FAMILY                          0.438838
# Property Type_TOWNHOUSE                             -0.236080
# School Rating_A                                      0.004043
# School Rating_A+                                    -0.061329
# School Rating_A-                                     0.052768
# City_Alameda                                        -0.028423
# City_Benicia                                         0.035759
# City_Berkeley                                        0.034501
# City_Brentwood                                       0.074911
# City_Castro Valley                                   0.032074
# City_Dublin                                         -0.026025
# City_Fremont                                         0.004282
# City_Lafayette                                      -0.043326
# City_Larkspur                                        0.015833
# City_Livermore                                       0.043142
# City_Los Gatos                                      -0.011795
# City_Martinez                                        0.008561
# City_Milpitas                                        0.024919
# City_Mountain View                                  -0.051804
# City_Palo Alto                                       0.027405
# City_Piedmont                                        0.002242
# City_Pleasanton                                      0.027548
# City_Redwood City                                    0.012803
# City_San Francisco                                  -0.066907
# City_San Jose                                        0.028958
# City_San Mateo                                      -0.071050
# City_San Ramon                                      -0.036223
# City_Santa Clara                                    -0.004686
# City_Sunnyvale                                       0.000075
# Construction Type_BUILDER_PLAN                      -0.221480
# Construction Type_BUILDER_SPEC                      -0.056419
# Construction Type_False                              0.234404
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER       -0.065137
# Listing Type_False                                   0.234404
# Listing Type_True                                   -0.234404
# County_Alameda                                       0.033105
# County_Contra Costa                                  0.026325
# County_Marin                                         0.015833
# County_San Francisco                                -0.066907
# County_San Mateo                                    -0.035859
# County_Santa Clara                                   0.009154
# County_Solano                                        0.035759
#
#                                                Number of Bedrooms  longitude  \
# Lot Area (sqf)                                           0.266084   0.088158
# Number of Bedrooms                                       1.000000   0.016330
# longitude                                                0.016330   1.000000
# latitude                                                 0.049593  -0.322227
# Number of Bathrooms                                      0.553899   0.021678
# Living Area (sqf)                                        0.693770  -0.023895
# Price per sqf ($)                                        0.021064  -0.272812
# Median Price Growth (%) in the Area                     -0.037798   0.621843
# Monthly Payment (($)[Tax&Ins])                          -0.054661  -0.296240
# Minimum Qualifying Income ($)                           -0.054661  -0.296240
# Unemployment Rate (%)                                    0.041200   0.233924
# City Population                                          0.035275   0.057116
# Total Crimes per 1000                                    0.028651  -0.607539
# Violent Crimes per 1000                                  0.040194  -0.344284
# Property Crimes per 1000                                 0.035158  -0.631392
# Burglary Crimes per 1000                                -0.058677  -0.593340
# Property Type_CONDO                                     -0.473273   0.044049
# Property Type_SINGLE_FAMILY                              0.496367  -0.082214
# Property Type_TOWNHOUSE                                 -0.124503   0.062189
# School Rating_A                                         -0.041208  -0.067419
# School Rating_A+                                        -0.064909  -0.197260
# School Rating_A-                                         0.091541   0.232832
# City_Alameda                                            -0.069604  -0.186825
# City_Benicia                                             0.006456  -0.071543
# City_Berkeley                                           -0.070745  -0.182384
# City_Brentwood                                           0.003841   0.351711
# City_Castro Valley                                       0.005817  -0.020952
# City_Dublin                                              0.079339   0.104049
# City_Fremont                                             0.001934   0.101316
# City_Lafayette                                          -0.001437  -0.032580
# City_Larkspur                                           -0.021838  -0.108377
# City_Livermore                                           0.045432   0.259914
# City_Los Gatos                                          -0.008845   0.046291
# City_Martinez                                            0.043003  -0.053128
# City_Milpitas                                            0.039892   0.078885
# City_Mountain View                                      -0.034963  -0.036459
# City_Palo Alto                                           0.022793  -0.071870
# City_Piedmont                                            0.018247  -0.040178
# City_Pleasanton                                          0.006904   0.107052
# City_Redwood City                                       -0.005790  -0.157772
# City_San Francisco                                       0.108391  -0.646709
# City_San Jose                                           -0.024499   0.445897
# City_San Mateo                                          -0.120016  -0.337062
# City_San Ramon                                           0.021836   0.063173
# City_Santa Clara                                        -0.024472   0.050870
# City_Sunnyvale                                          -0.008340   0.010933
# Construction Type_BUILDER_PLAN                          -0.082567   0.045034
# Construction Type_BUILDER_SPEC                           0.035916  -0.033136
# Construction Type_False                                  0.061128  -0.024435
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER           -0.035604   0.012829
# Listing Type_False                                       0.061128  -0.024435
# Listing Type_True                                       -0.061128   0.024435
# County_Alameda                                           0.003346   0.105495
# County_Contra Costa                                      0.034541   0.246403
# County_Marin                                            -0.021838  -0.108377
# County_San Francisco                                     0.108391  -0.646709
# County_San Mateo                                        -0.085566  -0.376061
# County_Santa Clara                                      -0.037889   0.441275
# County_Solano                                            0.006456  -0.071543
#
#                                                latitude  Number of Bathrooms  \
# Lot Area (sqf)                                 0.015417             0.005852
# Number of Bedrooms                             0.049593             0.553899
# longitude                                     -0.322227             0.021678
# latitude                                       1.000000             0.061529
# Number of Bathrooms                            0.061529             1.000000
# Living Area (sqf)                              0.155335             0.717195
# Price per sqf ($)                             -0.321191            -0.088917
# Median Price Growth (%) in the Area           -0.198552            -0.042221
# Monthly Payment (($)[Tax&Ins])                -0.714946            -0.084197
# Minimum Qualifying Income ($)                 -0.714946            -0.084197
# Unemployment Rate (%)                          0.727149             0.072494
# City Population                               -0.487826            -0.058544
# Total Crimes per 1000                          0.097563            -0.035680
# Violent Crimes per 1000                       -0.076122            -0.069399
# Property Crimes per 1000                       0.146703            -0.021031
# Burglary Crimes per 1000                      -0.121056            -0.125378
# Property Type_CONDO                           -0.181184            -0.255246
# Property Type_SINGLE_FAMILY                    0.188243             0.079193
# Property Type_TOWNHOUSE                       -0.045160             0.197702
# School Rating_A                               -0.028672             0.015892
# School Rating_A+                               0.045481             0.012800
# School Rating_A-                              -0.018988            -0.024145
# City_Alameda                                   0.166018            -0.025933
# City_Benicia                                   0.275518             0.010211
# City_Berkeley                                  0.227808            -0.120859
# City_Brentwood                                 0.389829             0.068516
# City_Castro Valley                             0.078877            -0.055075
# City_Dublin                                    0.111849             0.100759
# City_Fremont                                  -0.056350             0.065119
# City_Lafayette                                 0.141015             0.018764
# City_Larkspur                                  0.077801            -0.012491
# City_Livermore                                 0.108980            -0.022554
# City_Los Gatos                                -0.209338             0.013154
# City_Martinez                                  0.309642            -0.004714
# City_Milpitas                                 -0.070497             0.007918
# City_Mountain View                            -0.129667             0.012685
# City_Palo Alto                                -0.088317             0.024652
# City_Piedmont                                  0.049064             0.015684
# City_Pleasanton                                0.077907            -0.001940
# City_Redwood City                             -0.063979            -0.013744
# City_San Francisco                             0.274797             0.054387
# City_San Jose                                 -0.650797            -0.096613
# City_San Mateo                                -0.013894            -0.055027
# City_San Ramon                                 0.151064             0.075532
# City_Santa Clara                              -0.150407             0.013647
# City_Sunnyvale                                -0.147836             0.006198
# Construction Type_BUILDER_PLAN                 0.023732             0.159884
# Construction Type_BUILDER_SPEC                 0.003151             0.150952
# Construction Type_False                       -0.008430            -0.224886
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER -0.046024             0.042039
# Listing Type_False                            -0.008430            -0.224886
# Listing Type_True                              0.008430             0.224886
# County_Alameda                                 0.266538            -0.001667
# County_Contra Costa                            0.547471             0.090270
# County_Marin                                   0.077801            -0.012491
# County_San Francisco                           0.274797             0.054387
# County_San Mateo                              -0.084569            -0.038393
# County_Santa Clara                            -0.808671            -0.069741
# County_Solano                                  0.275518             0.010211
#
#                                                Living Area (sqf)  \
# Lot Area (sqf)                                          0.139062
# Number of Bedrooms                                      0.693770
# longitude                                              -0.023895
# latitude                                                0.155335
# Number of Bathrooms                                     0.717195
# Living Area (sqf)                                       1.000000
# Price per sqf ($)                                      -0.107213
# Median Price Growth (%) in the Area                    -0.127422
# Monthly Payment (($)[Tax&Ins])                         -0.121727
# Minimum Qualifying Income ($)                          -0.121727
# Unemployment Rate (%)                                   0.101833
# City Population                                        -0.053342
# Total Crimes per 1000                                   0.019560
# Violent Crimes per 1000                                -0.002969
# Property Crimes per 1000                                0.034330
# Burglary Crimes per 1000                               -0.087743
# Property Type_CONDO                                    -0.374396
# Property Type_SINGLE_FAMILY                             0.369268
# Property Type_TOWNHOUSE                                -0.065619
# School Rating_A                                        -0.037856
# School Rating_A+                                       -0.005247
# School Rating_A-                                        0.034490
# City_Alameda                                           -0.010112
# City_Benicia                                           -0.009666
# City_Berkeley                                          -0.078441
# City_Brentwood                                          0.159573
# City_Castro Valley                                     -0.022398
# City_Dublin                                             0.068736
# City_Fremont                                           -0.004145
# City_Lafayette                                          0.056409
# City_Larkspur                                          -0.000329
# City_Livermore                                         -0.006885
# City_Los Gatos                                          0.052094
# City_Martinez                                          -0.000700
# City_Milpitas                                          -0.024394
# City_Mountain View                                     -0.066978
# City_Palo Alto                                          0.056267
# City_Piedmont                                           0.043849
# City_Pleasanton                                        -0.009052
# City_Redwood City                                      -0.003014
# City_San Francisco                                      0.127229
# City_San Jose                                          -0.123941
# City_San Mateo                                         -0.064138
# City_San Ramon                                          0.064527
# City_Santa Clara                                       -0.052063
# City_Sunnyvale                                         -0.032373
# Construction Type_BUILDER_PLAN                          0.046223
# Construction Type_BUILDER_SPEC                          0.108982
# Construction Type_False                                -0.091706
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER          -0.012827
# Listing Type_False                                     -0.091706
# Listing Type_True                                       0.091706
# County_Alameda                                         -0.018401
# County_Contra Costa                                     0.162430
# County_Marin                                           -0.000329
# County_San Francisco                                    0.127229
# County_San Mateo                                       -0.025325
# County_Santa Clara                                     -0.155201
# County_Solano                                          -0.009666
#
#                                                Price per sqf ($)  \
# Lot Area (sqf)                                          0.108241
# Number of Bedrooms                                      0.021064
# longitude                                              -0.272812
# latitude                                               -0.321191
# Number of Bathrooms                                    -0.088917
# Living Area (sqf)                                      -0.107213
# Price per sqf ($)                                       1.000000
# Median Price Growth (%) in the Area                    -0.197857
# Monthly Payment (($)[Tax&Ins])                          0.477765
# Minimum Qualifying Income ($)                           0.477765
# Unemployment Rate (%)                                  -0.442513
# City Population                                         0.007549
# Total Crimes per 1000                                   0.161044
# Violent Crimes per 1000                                 0.006924
# Property Crimes per 1000                                0.177672
# Burglary Crimes per 1000                                0.181929
# Property Type_CONDO                                    -0.180568
# Property Type_SINGLE_FAMILY                             0.240656
# Property Type_TOWNHOUSE                                -0.119545
# School Rating_A                                         0.028796
# School Rating_A+                                        0.261573
# School Rating_A-                                       -0.261190
# City_Alameda                                           -0.063440
# City_Benicia                                           -0.135106
# City_Berkeley                                           0.022875
# City_Brentwood                                         -0.305103
# City_Castro Valley                                     -0.052647
# City_Dublin                                            -0.092021
# City_Fremont                                           -0.031344
# City_Lafayette                                          0.000803
# City_Larkspur                                           0.040529
# City_Livermore                                         -0.105027
# City_Los Gatos                                          0.120655
# City_Martinez                                          -0.177264
# City_Milpitas                                           0.017594
# City_Mountain View                                      0.160416
# City_Palo Alto                                          0.387539
# City_Piedmont                                          -0.009584
# City_Pleasanton                                        -0.040820
# City_Redwood City                                       0.135547
# City_San Francisco                                      0.076735
# City_San Jose                                          -0.046675
# City_San Mateo                                          0.091937
# City_San Ramon                                         -0.067075
# City_Santa Clara                                        0.092270
# City_Sunnyvale                                          0.126298
# Construction Type_BUILDER_PLAN                         -0.088658
# Construction Type_BUILDER_SPEC                          0.029448
# Construction Type_False                                 0.053691
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER           0.019944
# Listing Type_False                                      0.053691
# Listing Type_True                                      -0.053691
# County_Alameda                                         -0.151211
# County_Contra Costa                                    -0.337847
# County_Marin                                            0.040529
# County_San Francisco                                    0.076735
# County_San Mateo                                        0.320226
# County_Santa Clara                                      0.128142
# County_Solano                                          -0.135106
#
#                                                Median Price Growth (%) in the Area  \
# Lot Area (sqf)                                                            0.076748
# Number of Bedrooms                                                       -0.037798
# longitude                                                                 0.621843
# latitude                                                                 -0.198552
# Number of Bathrooms                                                      -0.042221
# Living Area (sqf)                                                        -0.127422
# Price per sqf ($)                                                        -0.197857
# Median Price Growth (%) in the Area                                       1.000000
# Monthly Payment (($)[Tax&Ins])                                           -0.363767
# Minimum Qualifying Income ($)                                            -0.363767
# Unemployment Rate (%)                                                     0.402317
# City Population                                                          -0.110867
# Total Crimes per 1000                                                    -0.478635
# Violent Crimes per 1000                                                  -0.424928
# Property Crimes per 1000                                                 -0.474603
# Burglary Crimes per 1000                                                 -0.432558
# Property Type_CONDO                                                       0.089196
# Property Type_SINGLE_FAMILY                                              -0.172362
# Property Type_TOWNHOUSE                                                   0.134197
# School Rating_A                                                           0.228893
# School Rating_A+                                                         -0.062745
# School Rating_A-                                                         -0.122371
# City_Alameda                                                              0.166000
# City_Benicia                                                              0.196317
# City_Berkeley                                                             0.152396
# City_Brentwood                                                           -0.103874
# City_Castro Valley                                                        0.116388
# City_Dublin                                                               0.156210
# City_Fremont                                                              0.270292
# City_Lafayette                                                           -0.040873
# City_Larkspur                                                             0.173890
# City_Livermore                                                            0.186393
# City_Los Gatos                                                            0.061392
# City_Martinez                                                            -0.069602
# City_Milpitas                                                             0.054975
# City_Mountain View                                                        0.077737
# City_Palo Alto                                                           -0.219314
# City_Piedmont                                                             0.038509
# City_Pleasanton                                                           0.144503
# City_Redwood City                                                        -0.246436
# City_San Francisco                                                       -0.656869
# City_San Jose                                                             0.256400
# City_San Mateo                                                           -0.386578
# City_San Ramon                                                           -0.072070
# City_Santa Clara                                                          0.074599
# City_Sunnyvale                                                            0.076496
# Construction Type_BUILDER_PLAN                                            0.084443
# Construction Type_BUILDER_SPEC                                           -0.056738
# Construction Type_False                                                  -0.047367
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER                             0.019713
# Listing Type_False                                                       -0.047367
# Listing Type_True                                                         0.047367
# County_Alameda                                                            0.530154
# County_Contra Costa                                                      -0.156669
# County_Marin                                                              0.173890
# County_San Francisco                                                     -0.656869
# County_San Mateo                                                         -0.528306
# County_Santa Clara                                                        0.340469
# County_Solano                                                             0.196317
#
#                                                Monthly Payment (($)[Tax&Ins])  \
# Lot Area (sqf)                                                      -0.060453
# Number of Bedrooms                                                  -0.054661
# longitude                                                           -0.296240
# latitude                                                            -0.714946
# Number of Bathrooms                                                 -0.084197
# Living Area (sqf)                                                   -0.121727
# Price per sqf ($)                                                    0.477765
# Median Price Growth (%) in the Area                                 -0.363767
# Monthly Payment (($)[Tax&Ins])                                       1.000000
# Minimum Qualifying Income ($)                                        1.000000
# Unemployment Rate (%)                                               -0.973022
# City Population                                                      0.433333
# Total Crimes per 1000                                                0.348028
# Violent Crimes per 1000                                              0.378760
# Property Crimes per 1000                                             0.307985
# Burglary Crimes per 1000                                             0.564842
# Property Type_CONDO                                                  0.140067
# Property Type_SINGLE_FAMILY                                         -0.081168
# Property Type_TOWNHOUSE                                             -0.055508
# School Rating_A                                                     -0.092725
# School Rating_A+                                                     0.096591
# School Rating_A-                                                    -0.015348
# City_Alameda                                                        -0.127326
# City_Benicia                                                        -0.338147
# City_Berkeley                                                       -0.116891
# City_Brentwood                                                      -0.443525
# City_Castro Valley                                                  -0.089272
# City_Dublin                                                         -0.119816
# City_Fremont                                                        -0.207320
# City_Lafayette                                                      -0.174522
# City_Larkspur                                                        0.030031
# City_Livermore                                                      -0.142967
# City_Los Gatos                                                       0.081613
# City_Martinez                                                       -0.297188
# City_Milpitas                                                        0.073083
# City_Mountain View                                                   0.103343
# City_Palo Alto                                                       0.204441
# City_Piedmont                                                       -0.029537
# City_Pleasanton                                                     -0.110837
# City_Redwood City                                                    0.229723
# City_San Francisco                                                   0.178832
# City_San Jose                                                        0.340856
# City_San Mateo                                                       0.360361
# City_San Ramon                                                      -0.307730
# City_Santa Clara                                                     0.099171
# City_Sunnyvale                                                       0.101693
# Construction Type_BUILDER_PLAN                                      -0.111504
# Construction Type_BUILDER_SPEC                                       0.029772
# Construction Type_False                                              0.073492
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER                        0.017397
# Listing Type_False                                                   0.073492
# Listing Type_True                                                   -0.073492
# County_Alameda                                                      -0.406640
# County_Contra Costa                                                 -0.668953
# County_Marin                                                         0.030031
# County_San Francisco                                                 0.178832
# County_San Mateo                                                     0.492477
# County_Santa Clara                                                   0.452618
# County_Solano                                                       -0.338147
#
#                                                Minimum Qualifying Income ($)  \
# Lot Area (sqf)                                                     -0.060453
# Number of Bedrooms                                                 -0.054661
# longitude                                                          -0.296240
# latitude                                                           -0.714946
# Number of Bathrooms                                                -0.084197
# Living Area (sqf)                                                  -0.121727
# Price per sqf ($)                                                   0.477765
# Median Price Growth (%) in the Area                                -0.363767
# Monthly Payment (($)[Tax&Ins])                                      1.000000
# Minimum Qualifying Income ($)                                       1.000000
# Unemployment Rate (%)                                              -0.973022
# City Population                                                     0.433333
# Total Crimes per 1000                                               0.348028
# Violent Crimes per 1000                                             0.378760
# Property Crimes per 1000                                            0.307985
# Burglary Crimes per 1000                                            0.564842
# Property Type_CONDO                                                 0.140067
# Property Type_SINGLE_FAMILY                                        -0.081168
# Property Type_TOWNHOUSE                                            -0.055508
# School Rating_A                                                    -0.092725
# School Rating_A+                                                    0.096591
# School Rating_A-                                                   -0.015348
# City_Alameda                                                       -0.127326
# City_Benicia                                                       -0.338147
# City_Berkeley                                                      -0.116891
# City_Brentwood                                                     -0.443525
# City_Castro Valley                                                 -0.089272
# City_Dublin                                                        -0.119816
# City_Fremont                                                       -0.207320
# City_Lafayette                                                     -0.174522
# City_Larkspur                                                       0.030031
# City_Livermore                                                     -0.142967
# City_Los Gatos                                                      0.081613
# City_Martinez                                                      -0.297188
# City_Milpitas                                                       0.073083
# City_Mountain View                                                  0.103343
# City_Palo Alto                                                      0.204441
# City_Piedmont                                                      -0.029537
# City_Pleasanton                                                    -0.110837
# City_Redwood City                                                   0.229723
# City_San Francisco                                                  0.178832
# City_San Jose                                                       0.340856
# City_San Mateo                                                      0.360361
# City_San Ramon                                                     -0.307730
# City_Santa Clara                                                    0.099171
# City_Sunnyvale                                                      0.101693
# Construction Type_BUILDER_PLAN                                     -0.111504
# Construction Type_BUILDER_SPEC                                      0.029772
# Construction Type_False                                             0.073492
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER                       0.017397
# Listing Type_False                                                  0.073492
# Listing Type_True                                                  -0.073492
# County_Alameda                                                     -0.406640
# County_Contra Costa                                                -0.668953
# County_Marin                                                        0.030031
# County_San Francisco                                                0.178832
# County_San Mateo                                                    0.492477
# County_Santa Clara                                                  0.452618
# County_Solano                                                      -0.338147
#
#                                                ...  \
# Lot Area (sqf)                                 ...
# Number of Bedrooms                             ...
# longitude                                      ...
# latitude                                       ...
# Number of Bathrooms                            ...
# Living Area (sqf)                              ...
# Price per sqf ($)                              ...
# Median Price Growth (%) in the Area            ...
# Monthly Payment (($)[Tax&Ins])                 ...
# Minimum Qualifying Income ($)                  ...
# Unemployment Rate (%)                          ...
# City Population                                ...
# Total Crimes per 1000                          ...
# Violent Crimes per 1000                        ...
# Property Crimes per 1000                       ...
# Burglary Crimes per 1000                       ...
# Property Type_CONDO                            ...
# Property Type_SINGLE_FAMILY                    ...
# Property Type_TOWNHOUSE                        ...
# School Rating_A                                ...
# School Rating_A+                               ...
# School Rating_A-                               ...
# City_Alameda                                   ...
# City_Benicia                                   ...
# City_Berkeley                                  ...
# City_Brentwood                                 ...
# City_Castro Valley                             ...
# City_Dublin                                    ...
# City_Fremont                                   ...
# City_Lafayette                                 ...
# City_Larkspur                                  ...
# City_Livermore                                 ...
# City_Los Gatos                                 ...
# City_Martinez                                  ...
# City_Milpitas                                  ...
# City_Mountain View                             ...
# City_Palo Alto                                 ...
# City_Piedmont                                  ...
# City_Pleasanton                                ...
# City_Redwood City                              ...
# City_San Francisco                             ...
# City_San Jose                                  ...
# City_San Mateo                                 ...
# City_San Ramon                                 ...
# City_Santa Clara                               ...
# City_Sunnyvale                                 ...
# Construction Type_BUILDER_PLAN                 ...
# Construction Type_BUILDER_SPEC                 ...
# Construction Type_False                        ...
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER  ...
# Listing Type_False                             ...
# Listing Type_True                              ...
# County_Alameda                                 ...
# County_Contra Costa                            ...
# County_Marin                                   ...
# County_San Francisco                           ...
# County_San Mateo                               ...
# County_Santa Clara                             ...
# County_Solano                                  ...
#
#                                                Construction Type_NEW_CONSTRUCTION_TYPE_OTHER  \
# Lot Area (sqf)                                                                     -0.065137
# Number of Bedrooms                                                                 -0.035604
# longitude                                                                           0.012829
# latitude                                                                           -0.046024
# Number of Bathrooms                                                                 0.042039
# Living Area (sqf)                                                                  -0.012827
# Price per sqf ($)                                                                   0.019944
# Median Price Growth (%) in the Area                                                 0.019713
# Monthly Payment (($)[Tax&Ins])                                                      0.017397
# Minimum Qualifying Income ($)                                                       0.017397
# Unemployment Rate (%)                                                              -0.021684
# City Population                                                                     0.001011
# Total Crimes per 1000                                                              -0.030243
# Violent Crimes per 1000                                                            -0.026392
# Property Crimes per 1000                                                           -0.029906
# Burglary Crimes per 1000                                                           -0.013554
# Property Type_CONDO                                                                 0.138267
# Property Type_SINGLE_FAMILY                                                        -0.125805
# Property Type_TOWNHOUSE                                                             0.009386
# School Rating_A                                                                     0.020490
# School Rating_A+                                                                    0.018895
# School Rating_A-                                                                   -0.033313
# City_Alameda                                                                       -0.016895
# City_Benicia                                                                       -0.011506
# City_Berkeley                                                                      -0.015510
# City_Brentwood                                                                     -0.022355
# City_Castro Valley                                                                 -0.011846
# City_Dublin                                                                        -0.015898
# City_Fremont                                                                        0.027611
# City_Lafayette                                                                      0.044373
# City_Larkspur                                                                      -0.004383
# City_Livermore                                                                     -0.018970
# City_Los Gatos                                                                     -0.012656
# City_Martinez                                                                      -0.014979
# City_Milpitas                                                                      -0.011333
# City_Mountain View                                                                  0.103196
# City_Palo Alto                                                                     -0.014149
# City_Piedmont                                                                      -0.003919
# City_Pleasanton                                                                    -0.014707
# City_Redwood City                                                                   0.044162
# City_San Francisco                                                                 -0.032081
# City_San Jose                                                                       0.017361
# City_San Mateo                                                                     -0.024939
# City_San Ramon                                                                      0.015228
# City_Santa Clara                                                                   -0.015379
# City_Sunnyvale                                                                      0.014491
# Construction Type_BUILDER_PLAN                                                     -0.026332
# Construction Type_BUILDER_SPEC                                                     -0.015379
# Construction Type_False                                                            -0.256400
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER                                       1.000000
# Listing Type_False                                                                 -0.256400
# Listing Type_True                                                                   0.256400
# County_Alameda                                                                     -0.019200
# County_Contra Costa                                                                -0.002483
# County_Marin                                                                       -0.004383
# County_San Francisco                                                               -0.032081
# County_San Mateo                                                                   -0.003104
# County_Santa Clara                                                                  0.045326
# County_Solano                                                                      -0.011506
#
#                                                Listing Type_False  \
# Lot Area (sqf)                                           0.234404
# Number of Bedrooms                                       0.061128
# longitude                                               -0.024435
# latitude                                                -0.008430
# Number of Bathrooms                                     -0.224886
# Living Area (sqf)                                       -0.091706
# Price per sqf ($)                                        0.053691
# Median Price Growth (%) in the Area                     -0.047367
# Monthly Payment (($)[Tax&Ins])                           0.073492
# Minimum Qualifying Income ($)                            0.073492
# Unemployment Rate (%)                                   -0.084591
# City Population                                          0.085234
# Total Crimes per 1000                                    0.102331
# Violent Crimes per 1000                                  0.125567
# Property Crimes per 1000                                 0.097782
# Burglary Crimes per 1000                                 0.102578
# Property Type_CONDO                                     -0.091427
# Property Type_SINGLE_FAMILY                              0.316345
# Property Type_TOWNHOUSE                                 -0.333788
# School Rating_A                                         -0.168690
# School Rating_A+                                        -0.012211
# School Rating_A-                                         0.143504
# City_Alameda                                            -0.096672
# City_Benicia                                             0.044877
# City_Berkeley                                            0.060493
# City_Brentwood                                          -0.032430
# City_Castro Valley                                       0.046199
# City_Dublin                                             -0.049858
# City_Fremont                                            -0.219122
# City_Lafayette                                          -0.041869
# City_Larkspur                                            0.017094
# City_Livermore                                           0.073987
# City_Los Gatos                                           0.027975
# City_Martinez                                            0.003803
# City_Milpitas                                            0.044202
# ...
# latitude                                                   0.274797
# Number of Bathrooms                                        0.054387
# Living Area (sqf)                                          0.127229
# Price per sqf ($)                                          0.076735
# Median Price Growth (%) in the Area                       -0.656869
# Monthly Payment (($)[Tax&Ins])                             0.178832
# Minimum Qualifying Income ($)                              0.178832
# Unemployment Rate (%)                                     -0.222597
# City Population                                            0.375202
# Total Crimes per 1000                                      0.810756
# Violent Crimes per 1000                                    0.711428
# Property Crimes per 1000                                   0.818009
# Burglary Crimes per 1000                                   0.511959
# Property Type_CONDO                                       -0.182869
# Property Type_SINGLE_FAMILY                                0.255004
# Property Type_TOWNHOUSE                                   -0.136918
# School Rating_A                                           -0.170013
# School Rating_A+                                          -0.226991
# School Rating_A-                                           0.340454
# City_Alameda                                              -0.064980
# City_Benicia                                              -0.044255
# City_Berkeley                                             -0.059655
# City_Brentwood                                            -0.085979
# City_Castro Valley                                        -0.045559
# City_Dublin                                               -0.061147
# City_Fremont                                              -0.105804
# City_Lafayette                                            -0.033832
# City_Larkspur                                             -0.016857
# City_Livermore                                            -0.072962
# City_Los Gatos                                            -0.048677
# City_Martinez                                             -0.057611
# City_Milpitas                                             -0.043589
# City_Mountain View                                        -0.061638
# City_Palo Alto                                            -0.054418
# City_Piedmont                                             -0.015074
# City_Pleasanton                                           -0.056565
# City_Redwood City                                         -0.061147
# City_San Francisco                                         1.000000
# City_San Jose                                             -0.203300
# City_San Mateo                                            -0.095920
# City_San Ramon                                            -0.059655
# City_Santa Clara                                          -0.059150
# City_Sunnyvale                                            -0.060653
# Construction Type_BUILDER_PLAN                            -0.068147
# Construction Type_BUILDER_SPEC                            -0.041198
# Construction Type_False                                    0.087923
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER             -0.032081
# Listing Type_False                                         0.087923
# Listing Type_True                                         -0.087923
# County_Alameda                                            -0.207525
# County_Contra Costa                                       -0.129679
# County_Marin                                              -0.016857
# County_San Francisco                                       1.000000
# County_San Mateo                                          -0.131087
# County_Santa Clara                                        -0.269958
# County_Solano                                             -0.044255
#
#                                                County_San Mateo  \
# Lot Area (sqf)                                        -0.035859
# Number of Bedrooms                                    -0.085566
# longitude                                             -0.376061
# latitude                                              -0.084569
# Number of Bathrooms                                   -0.038393
# Living Area (sqf)                                     -0.025325
# Price per sqf ($)                                      0.320226
# Median Price Growth (%) in the Area                   -0.528306
# Monthly Payment (($)[Tax&Ins])                         0.492477
# Minimum Qualifying Income ($)                          0.492477
# Unemployment Rate (%)                                 -0.380992
# City Population                                       -0.286810
# Total Crimes per 1000                                 -0.128272
# Violent Crimes per 1000                               -0.180643
# Property Crimes per 1000                              -0.131942
# Burglary Crimes per 1000                               0.173167
# Property Type_CONDO                                    0.113990
# Property Type_SINGLE_FAMILY                           -0.089109
# Property Type_TOWNHOUSE                               -0.012785
# School Rating_A                                        0.048348
# School Rating_A+                                       0.380527
# School Rating_A-                                      -0.385035
# City_Alameda                                          -0.069035
# City_Benicia                                          -0.047017
# City_Berkeley                                         -0.063377
# City_Brentwood                                        -0.091344
# City_Castro Valley                                    -0.048403
# City_Dublin                                           -0.064963
# City_Fremont                                          -0.112407
# City_Lafayette                                        -0.035943
# City_Larkspur                                         -0.017909
# City_Livermore                                        -0.077515
# City_Los Gatos                                        -0.051715
# City_Martinez                                         -0.061206
# City_Milpitas                                         -0.046309
# City_Mountain View                                    -0.065484
# City_Palo Alto                                         0.415127
# City_Piedmont                                         -0.016015
# City_Pleasanton                                       -0.060095
# City_Redwood City                                      0.466465
# City_San Francisco                                    -0.131087
# City_San Jose                                         -0.215987
# City_San Mateo                                         0.731732
# City_San Ramon                                        -0.063377
# City_Santa Clara                                      -0.062841
# City_Sunnyvale                                        -0.064438
# Construction Type_BUILDER_PLAN                        -0.039078
# Construction Type_BUILDER_SPEC                         0.108515
# Construction Type_False                               -0.022416
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER         -0.003104
# Listing Type_False                                    -0.022416
# Listing Type_True                                      0.022416
# County_Alameda                                        -0.220476
# County_Contra Costa                                   -0.137772
# County_Marin                                          -0.017909
# County_San Francisco                                  -0.131087
# County_San Mateo                                       1.000000
# County_Santa Clara                                    -0.286805
# County_Solano                                         -0.047017
#
#                                                County_Santa Clara  \
# Lot Area (sqf)                                           0.009154
# Number of Bedrooms                                      -0.037889
# longitude                                                0.441275
# latitude                                                -0.808671
# Number of Bathrooms                                     -0.069741
# Living Area (sqf)                                       -0.155201
# Price per sqf ($)                                        0.128142
# Median Price Growth (%) in the Area                      0.340469
# Monthly Payment (($)[Tax&Ins])                           0.452618
# Minimum Qualifying Income ($)                            0.452618
# Unemployment Rate (%)                                   -0.549671
# City Population                                          0.554368
# Total Crimes per 1000                                   -0.028223
# Violent Crimes per 1000                                  0.157872
# Property Crimes per 1000                                -0.084058
# Burglary Crimes per 1000                                 0.144857
# Property Type_CONDO                                      0.143293
# Property Type_SINGLE_FAMILY                             -0.120314
# Property Type_TOWNHOUSE                                 -0.004413
# School Rating_A                                         -0.226440
# School Rating_A+                                        -0.144010
# School Rating_A-                                         0.309039
# City_Alameda                                            -0.142169
# City_Benicia                                            -0.096826
# City_Berkeley                                           -0.130519
# City_Brentwood                                          -0.188114
# City_Castro Valley                                      -0.099680
# City_Dublin                                             -0.133784
# City_Fremont                                            -0.231489
# City_Lafayette                                          -0.074021
# City_Larkspur                                           -0.036882
# City_Livermore                                          -0.159634
# City_Los Gatos                                           0.180314
# City_Martinez                                           -0.126048
# City_Milpitas                                            0.161467
# City_Mountain View                                       0.228323
# City_Palo Alto                                          -0.119061
# City_Piedmont                                           -0.032981
# City_Pleasanton                                         -0.123758
# City_Redwood City                                       -0.133784
# City_San Francisco                                      -0.269958
# City_San Jose                                            0.753078
# City_San Mateo                                          -0.209864
# City_San Ramon                                          -0.130519
# City_Santa Clara                                         0.219106
# City_Sunnyvale                                           0.224677
# Construction Type_BUILDER_PLAN                          -0.085797
# Construction Type_BUILDER_SPEC                          -0.030666
# Construction Type_False                                  0.075150
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER            0.045326
# Listing Type_False                                       0.075150
# Listing Type_True                                       -0.075150
# County_Alameda                                          -0.454046
# County_Contra Costa                                     -0.283726
# County_Marin                                            -0.036882
# County_San Francisco                                    -0.269958
# County_San Mateo                                        -0.286805
# County_Santa Clara                                       1.000000
# County_Solano                                           -0.096826
#
#                                                County_Solano
# Lot Area (sqf)                                      0.035759
# Number of Bedrooms                                  0.006456
# longitude                                          -0.071543
# latitude                                            0.275518
# Number of Bathrooms                                 0.010211
# Living Area (sqf)                                  -0.009666
# Price per sqf ($)                                  -0.135106
# Median Price Growth (%) in the Area                 0.196317
# Monthly Payment (($)[Tax&Ins])                     -0.338147
# Minimum Qualifying Income ($)                      -0.338147
# Unemployment Rate (%)                               0.415716
# City Population                                    -0.115752
# Total Crimes per 1000                              -0.135906
# Violent Crimes per 1000                            -0.176859
# Property Crimes per 1000                           -0.132016
# Burglary Crimes per 1000                           -0.082322
# Property Type_CONDO                                -0.011309
# Property Type_SINGLE_FAMILY                         0.013518
# Property Type_TOWNHOUSE                            -0.005304
# School Rating_A                                    -0.060979
# School Rating_A+                                   -0.081415
# School Rating_A-                                    0.122111
# City_Alameda                                       -0.023306
# City_Benicia                                        1.000000
# City_Berkeley                                      -0.021396
# City_Brentwood                                     -0.030838
# City_Castro Valley                                 -0.016341
# City_Dublin                                        -0.021932
# City_Fremont                                       -0.037949
# City_Lafayette                                     -0.012134
# City_Larkspur                                      -0.006046
# City_Livermore                                     -0.026169
# City_Los Gatos                                     -0.017459
# City_Martinez                                      -0.020663
# City_Milpitas                                      -0.015634
# City_Mountain View                                 -0.022108
# City_Palo Alto                                     -0.019518
# City_Piedmont                                      -0.005407
# City_Pleasanton                                    -0.020288
# City_Redwood City                                  -0.021932
# City_San Francisco                                 -0.044255
# City_San Jose                                      -0.072918
# City_San Mateo                                     -0.034404
# City_San Ramon                                     -0.021396
# City_Santa Clara                                   -0.021215
# City_Sunnyvale                                     -0.021755
# Construction Type_BUILDER_PLAN                     -0.036324
# Construction Type_BUILDER_SPEC                     -0.021215
# Construction Type_False                             0.044877
# Construction Type_NEW_CONSTRUCTION_TYPE_OTHER      -0.011506
# Listing Type_False                                  0.044877
# Listing Type_True                                  -0.044877
# County_Alameda                                     -0.074433
# County_Contra Costa                                -0.046512
# County_Marin                                       -0.006046
# County_San Francisco                               -0.044255
# County_San Mateo                                   -0.047017
# County_Santa Clara                                 -0.096826
# County_Solano                                       1.000000
#
# [59 rows x 59 columns]

# %%
#plotting correlation between all features (numerical and categorical, after getting dummies)
plt.figure(figsize=(30,20))
_ = sns.heatmap(final_data.corr())

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2176 entries, 0 to 2175
# Data columns (total 59 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lot Area (sqf)                                 2176 non-null   float64
#  1   Number of Bedrooms                             2176 non-null   float64
#  2   longitude                                      2176 non-null   float64
#  3   latitude                                       2176 non-null   float64
#  4   Number of Bathrooms                            2176 non-null   float64
#  5   Living Area (sqf)                              2176 non-null   float64
#  6   Price per sqf ($)                              2176 non-null   float64
#  7   Median Price Growth (%) in the Area            2176 non-null   float64
#  8   Monthly Payment (($)[Tax&Ins])                 2176 non-null   int64
#  9   Minimum Qualifying Income ($)                  2176 non-null   int64
#  10  Unemployment Rate (%)                          2176 non-null   float64
#  11  City Population                                2176 non-null   int64
#  12  Total Crimes per 1000                          2176 non-null   float64
#  13  Violent Crimes per 1000                        2176 non-null   float64
#  14  Property Crimes per 1000                       2176 non-null   float64
#  15  Burglary Crimes per 1000                       2176 non-null   float64
#  16  Property Type_CONDO                            2176 non-null   uint8
#  17  Property Type_SINGLE_FAMILY                    2176 non-null   uint8
#  18  Property Type_TOWNHOUSE                        2176 non-null   uint8
#  19  School Rating_A                                2176 non-null   uint8
#  20  School Rating_A+                               2176 non-null   uint8
#  21  School Rating_A-                               2176 non-null   uint8
#  22  City_Alameda                                   2176 non-null   uint8
#  23  City_Benicia                                   2176 non-null   uint8
#  24  City_Berkeley                                  2176 non-null   uint8
#  25  City_Brentwood                                 2176 non-null   uint8
#  26  City_Castro Valley                             2176 non-null   uint8
#  27  City_Dublin                                    2176 non-null   uint8
#  28  City_Fremont                                   2176 non-null   uint8
#  29  City_Lafayette                                 2176 non-null   uint8
#  30  City_Larkspur                                  2176 non-null   uint8
#  31  City_Livermore                                 2176 non-null   uint8
#  32  City_Los Gatos                                 2176 non-null   uint8
#  33  City_Martinez                                  2176 non-null   uint8
#  34  City_Milpitas                                  2176 non-null   uint8
#  35  City_Mountain View                             2176 non-null   uint8
#  36  City_Palo Alto                                 2176 non-null   uint8
#  37  City_Piedmont                                  2176 non-null   uint8
#  38  City_Pleasanton                                2176 non-null   uint8
#  39  City_Redwood City                              2176 non-null   uint8
#  40  City_San Francisco                             2176 non-null   uint8
#  41  City_San Jose                                  2176 non-null   uint8
#  42  City_San Mateo                                 2176 non-null   uint8
#  43  City_San Ramon                                 2176 non-null   uint8
#  44  City_Santa Clara                               2176 non-null   uint8
#  45  City_Sunnyvale                                 2176 non-null   uint8
#  46  Construction Type_BUILDER_PLAN                 2176 non-null   uint8
#  47  Construction Type_BUILDER_SPEC                 2176 non-null   uint8
#  48  Construction Type_False                        2176 non-null   uint8
#  49  Construction Type_NEW_CONSTRUCTION_TYPE_OTHER  2176 non-null   uint8
#  50  Listing Type_False                             2176 non-null   uint8
#  51  Listing Type_True                              2176 non-null   uint8
#  52  County_Alameda                                 2176 non-null   uint8
#  53  County_Contra Costa                            2176 non-null   uint8
#  54  County_Marin                                   2176 non-null   uint8
#  55  County_San Francisco                           2176 non-null   uint8
#  56  County_San Mateo                               2176 non-null   uint8
#  57  County_Santa Clara                             2176 non-null   uint8
#  58  County_Solano                                  2176 non-null   uint8
# dtypes: float64(13), int64(3), uint8(43)
# memory usage: 380.4 KB

# %%
final_data.columns
# Out:
# Index(['Lot Area (sqf)', 'Number of Bedrooms', 'longitude', 'latitude',
#        'Number of Bathrooms', 'Living Area (sqf)', 'Price per sqf ($)',
#        'Median Price Growth (%) in the Area', 'Monthly Payment (($)[Tax&Ins])',
#        'Minimum Qualifying Income ($)', 'Unemployment Rate (%)',
#        'City Population', 'Total Crimes per 1000', 'Violent Crimes per 1000',
#        'Property Crimes per 1000', 'Burglary Crimes per 1000',
#        'Property Type_CONDO', 'Property Type_SINGLE_FAMILY',
#        'Property Type_TOWNHOUSE', 'School Rating_A', 'School Rating_A+',
#        'School Rating_A-', 'City_Alameda', 'City_Benicia', 'City_Berkeley',
#        'City_Brentwood', 'City_Castro Valley', 'City_Dublin', 'City_Fremont',
#        'City_Lafayette', 'City_Larkspur', 'City_Livermore', 'City_Los Gatos',
#        'City_Martinez', 'City_Milpitas', 'City_Mountain View',
#        'City_Palo Alto', 'City_Piedmont', 'City_Pleasanton',
#        'City_Redwood City', 'City_San Francisco', 'City_San Jose',
#        'City_San Mateo', 'City_San Ramon', 'City_Santa Clara',
#        'City_Sunnyvale', 'Construction Type_BUILDER_PLAN',
#        'Construction Type_BUILDER_SPEC', 'Construction Type_False',
#        'Construction Type_NEW_CONSTRUCTION_TYPE_OTHER', 'Listing Type_False',
#        'Listing Type_True', 'County_Alameda', 'County_Contra Costa',
#        'County_Marin', 'County_San Francisco', 'County_San Mateo',
#        'County_Santa Clara', 'County_Solano'],
#       dtype='object')

# %%
final_data.describe()
# Out:
#        Lot Area (sqf)  Number of Bedrooms    longitude     latitude  \
# count     2176.000000         2176.000000  2176.000000  2176.000000
# mean      3364.876280            3.065257  -122.036063    37.565162
# std       4381.297426            1.022670     0.222295     0.227663
# min          0.000000            0.000000  -122.552390    37.097992
# 25%          0.000000            2.000000  -122.241795    37.358781
# 50%       2785.662000            3.000000  -121.963440    37.542442
# 75%       6098.400000            4.000000  -121.875487    37.741655
# max     149411.000000            9.000000  -121.492836    38.082703
#
#        Number of Bathrooms  Living Area (sqf)  Price per sqf ($)  \
# count          2176.000000        2176.000000        2176.000000
# mean              2.428768        1663.312040         837.465074
# std               0.879122         570.391679         322.307683
# min               0.000000         205.000000         269.000000
# 25%               2.000000        1239.500000         637.750000
# 50%               2.000000        1601.500000         785.500000
# 75%               3.000000        2033.000000         976.000000
# max               8.000000        5768.000000        4271.000000
#
#        Median Price Growth (%) in the Area  Monthly Payment (($)[Tax&Ins])  \
# count                          2176.000000                     2176.000000
# mean                             -2.172564                     7270.900735
# std                               2.421630                     1628.899838
# min                              -6.700000                     2900.000000
# 25%                              -3.200000                     6150.000000
# 50%                              -1.100000                     8100.000000
# 75%                               0.000000                     8230.000000
# max                               6.600000                     9420.000000
#
#        Minimum Qualifying Income ($)  ...  \
# count                    2176.000000  ...
# mean                   218127.022059  ...
# std                     48866.995143  ...
# min                     87000.000000  ...
# 25%                    184500.000000  ...
# 50%                    243000.000000  ...
# 75%                    246900.000000  ...
# max                    282600.000000  ...
#
#        Construction Type_NEW_CONSTRUCTION_TYPE_OTHER  Listing Type_False  \
# count                                    2176.000000         2176.000000
# mean                                        0.008272            0.887408
# std                                         0.090595            0.316166
# min                                         0.000000            0.000000
# 25%                                         0.000000            1.000000
# 50%                                         0.000000            1.000000
# 75%                                         0.000000            1.000000
# max                                         1.000000            1.000000
#
#        Listing Type_True  County_Alameda  County_Contra Costa  County_Marin  \
# count        2176.000000     2176.000000          2176.000000   2176.000000
# mean            0.112592        0.258732             0.119945      0.002298
# std             0.316166        0.438039             0.324972      0.047891
# min             0.000000        0.000000             0.000000      0.000000
# 25%             0.000000        0.000000             0.000000      0.000000
# 50%             0.000000        0.000000             0.000000      0.000000
# 75%             0.000000        1.000000             0.000000      0.000000
# max             1.000000        1.000000             1.000000      1.000000
#
#        County_San Francisco  County_San Mateo  County_Santa Clara  \
# count           2176.000000       2176.000000         2176.000000
# mean               0.109835          0.122243            0.371324
# std                0.312755          0.327641            0.483270
# min                0.000000          0.000000            0.000000
# 25%                0.000000          0.000000            0.000000
# 50%                0.000000          0.000000            0.000000
# 75%                0.000000          0.000000            1.000000
# max                1.000000          1.000000            1.000000
#
#        County_Solano
# count    2176.000000
# mean        0.015625
# std         0.124048
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 59 columns]

# %% [markdown]
# Some counties have a higher impact on the price than others. To evaluate price per sqf depending on the area it is usefull to put longitude and latitude information on the graph.

# %%
import matplotlib
import matplotlib.pyplot as plt

img = matplotlib.image.imread('Bay Area Map.png')

# %%
plt.figure(figsize=(15,8))
plt.imshow(img)

# %% [markdown]
# # Plotting Real Estate pricing information

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=data1, hue='Price per sqf ($)', palette = 'coolwarm')
plt.title ('Price per sqf ($) Distribution in Bay Area')
# Out:
# Text(0.5, 1.0, 'Price per sqf ($) Distribution in Bay Area')

# %% [markdown]
# Price per sqf does not give significant information on each loccation. We can see that in San Francisco city there are some properties with very high price per sqf, as well as very low. On the side of the Bay further from the ocean property price per sqf is lower.

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data= data, hue = 'Median Home Price', palette='coolwarm')
plt.title ('Median Home Price in Bay Area')
# Out:
# Text(0.5, 1.0, 'Median Home Price in Bay Area')

# %% [markdown]
# Median house prices shows significant higher real estate prices in San Mateo, Redwood City, Palo Alto areas. High prices in San Francisco city and San Jose, Sunnyvale areas.

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=data1, hue = 'Median Price Growth (%) in the Area', palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# Highest price growth is in San Jose, Sunnyvale Area, Oakland, Berkeley,Piedmont prices were stable.

# %%
# scaling data:

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(final_data)

# %%
scaled_df = pd.DataFrame(scaled_df, columns= 
['Lot Area (sqf)', 'Number of Bedrooms', 'longitude', 'latitude',
       'Number of Bathrooms', 'Living Area (sqf)', 'Price per sqf ($)',
       'Median Price Growth (%) in the Area', 'Monthly Payment (($)[Tax&Ins])',
       'Minimum Qualifying Income ($)', 'Unemployment Rate (%)',
       'City Population', 'Total Crimes per 1000', 'Violent Crimes per 1000',
       'Property Crimes per 1000', 'Burglary Crimes per 1000',
       'Property Type_CONDO', 'Property Type_SINGLE_FAMILY',
       'Property Type_TOWNHOUSE', 'School Rating_A', 'School Rating_A+',
       'School Rating_A-', 'City_Alameda', 'City_Benicia', 'City_Berkeley',
       'City_Brentwood', 'City_Castro Valley', 'City_Dublin', 'City_Fremont',
       'City_Lafayette', 'City_Larkspur', 'City_Livermore', 'City_Los Gatos',
       'City_Martinez', 'City_Milpitas', 'City_Mountain View',
       'City_Palo Alto', 'City_Piedmont', 'City_Pleasanton',
       'City_Redwood City', 'City_San Francisco', 'City_San Jose',
       'City_San Mateo', 'City_San Ramon', 'City_Santa Clara',
       'City_Sunnyvale', 'Construction Type_BUILDER_PLAN',
       'Construction Type_BUILDER_SPEC', 'Construction Type_False',
       'Construction Type_NEW_CONSTRUCTION_TYPE_OTHER', 'Listing Type_False',
       'Listing Type_True', 'County_Alameda', 'County_Contra Costa',
       'County_Marin', 'County_San Francisco', 'County_San Mateo',
       'County_Santa Clara', 'County_Solano'])

# %%
scaled_df.head()
# Out:
#    Lot Area (sqf)  Number of Bedrooms  longitude  latitude  \
# 0       -0.083006           -1.041882  -1.944514  0.838395
# 1       -0.054763            0.914232  -1.899204  0.670258
# 2       -0.198363            0.914232  -1.590085  0.753338
# 3       -0.075051           -0.063825  -1.792655  0.805972
# 4       -0.369409           -1.041882  -2.048544  0.834824
#
#    Number of Bathrooms  Living Area (sqf)  Price per sqf ($)  \
# 0            -1.625596          -1.096537           0.377164
# 1            -0.487836           0.318605          -1.087612
# 2             1.787685           1.344452          -1.329672
# 3            -1.625596          -0.338989          -0.491771
# 4            -1.625596          -1.119334           0.392681
#
#    Median Price Growth (%) in the Area  Monthly Payment (($)[Tax&Ins])  \
# 0                            -1.870012                         0.50911
# 1                            -1.870012                         0.50911
# 2                            -1.870012                         0.50911
# 3                            -1.870012                         0.50911
# 4                            -1.870012                         0.50911
#
#    Minimum Qualifying Income ($)  ...  \
# 0                        0.50911  ...
# 1                        0.50911  ...
# 2                        0.50911  ...
# 3                        0.50911  ...
# 4                        0.50911  ...
#
#    Construction Type_NEW_CONSTRUCTION_TYPE_OTHER  Listing Type_False  \
# 0                                      -0.091329            0.356198
# 1                                      -0.091329            0.356198
# 2                                      -0.091329            0.356198
# 3                                      -0.091329            0.356198
# 4                                      -0.091329            0.356198
#
#    Listing Type_True  County_Alameda  County_Contra Costa  County_Marin  \
# 0          -0.356198       -0.590795            -0.369178      -0.04799
# 1          -0.356198       -0.590795            -0.369178      -0.04799
# 2          -0.356198       -0.590795            -0.369178      -0.04799
# 3          -0.356198       -0.590795            -0.369178      -0.04799
# 4          -0.356198       -0.590795            -0.369178      -0.04799
#
#    County_San Francisco  County_San Mateo  County_Santa Clara  County_Solano
# 0              2.846858         -0.373185           -0.768533      -0.125988
# 1              2.846858         -0.373185           -0.768533      -0.125988
# 2              2.846858         -0.373185           -0.768533      -0.125988
# 3              2.846858         -0.373185           -0.768533      -0.125988
# 4              2.846858         -0.373185           -0.768533      -0.125988
#
# [5 rows x 59 columns]

# %%
#sns.pairplot(scaled_df)

# %%
from sklearn.model_selection import train_test_split

# %%
X= scaled_df.drop("Price per sqf ($)", axis=1)

y = scaled_df['Price per sqf ($)']

# %%
X
# Out:
#       Lot Area (sqf)  Number of Bedrooms  longitude  latitude  \
# 0          -0.083006           -1.041882  -1.944514  0.838395
# 1          -0.054763            0.914232  -1.899204  0.670258
# 2          -0.198363            0.914232  -1.590085  0.753338
# 3          -0.075051           -0.063825  -1.792655  0.805972
# 4          -0.369409           -1.041882  -2.048544  0.834824
# ...              ...                 ...        ...       ...
# 2171        1.058627           -0.063825  -2.204768  1.642442
# 2172       -0.768121            0.914232  -2.323242  1.615993
# 2173        0.493831           -1.041882  -2.265265  1.614267
# 2174       -0.604041           -2.019940  -2.244365  1.650548
# 2175        1.469337           -0.063825  -2.253904  1.582656
#
#       Number of Bathrooms  Living Area (sqf)  \
# 0               -1.625596          -1.096537
# 1               -0.487836           0.318605
# 2                1.787685           1.344452
# 3               -1.625596          -0.338989
# 4               -1.625596          -1.119334
# ...                   ...                ...
# 2171            -0.487836           0.108175
# 2172             0.649925           0.863970
# 2173            -0.487836          -0.198702
# 2174            -1.625596          -1.678727
# 2175             0.649925           0.870984
#
#       Median Price Growth (%) in the Area  Monthly Payment (($)[Tax&Ins])  \
# 0                               -1.870012                         0.50911
# 1                               -1.870012                         0.50911
# 2                               -1.870012                         0.50911
# 3                               -1.870012                         0.50911
# 4                               -1.870012                         0.50911
# ...                                   ...                             ...
# 2171                             3.623420                         0.62578
# 2172                             3.623420                         0.62578
# 2173                             3.623420                         0.62578
# 2174                             3.623420                         0.62578
# 2175                             3.623420                         0.62578
#
#       Minimum Qualifying Income ($)  Unemployment Rate (%)  ...  \
# 0                           0.50911              -0.633701  ...
# 1                           0.50911              -0.633701  ...
# 2                           0.50911              -0.633701  ...
# 3                           0.50911              -0.633701  ...
# 4                           0.50911              -0.633701  ...
# ...                             ...                    ...  ...
# 2171                        0.62578              -0.735601  ...
# 2172                        0.62578              -0.735601  ...
# 2173                        0.62578              -0.735601  ...
# 2174                        0.62578              -0.735601  ...
# 2175                        0.62578              -0.735601  ...
#
#       Construction Type_NEW_CONSTRUCTION_TYPE_OTHER  Listing Type_False  \
# 0                                         -0.091329            0.356198
# 1                                         -0.091329            0.356198
# 2                                         -0.091329            0.356198
# 3                                         -0.091329            0.356198
# 4                                         -0.091329            0.356198
# ...                                             ...                 ...
# 2171                                      -0.091329            0.356198
# 2172                                      -0.091329            0.356198
# 2173                                      -0.091329            0.356198
# 2174                                      -0.091329            0.356198
# 2175                                      -0.091329            0.356198
#
#       Listing Type_True  County_Alameda  County_Contra Costa  County_Marin  \
# 0             -0.356198       -0.590795            -0.369178     -0.047990
# 1             -0.356198       -0.590795            -0.369178     -0.047990
# 2             -0.356198       -0.590795            -0.369178     -0.047990
# 3             -0.356198       -0.590795            -0.369178     -0.047990
# 4             -0.356198       -0.590795            -0.369178     -0.047990
# ...                 ...             ...                  ...           ...
# 2171          -0.356198       -0.590795            -0.369178     20.837466
# 2172          -0.356198       -0.590795            -0.369178     20.837466
# 2173          -0.356198       -0.590795            -0.369178     20.837466
# 2174          -0.356198       -0.590795            -0.369178     20.837466
# 2175          -0.356198       -0.590795            -0.369178     20.837466
#
#       County_San Francisco  County_San Mateo  County_Santa Clara  \
# 0                 2.846858         -0.373185           -0.768533
# 1                 2.846858         -0.373185           -0.768533
# 2                 2.846858         -0.373185           -0.768533
# 3                 2.846858         -0.373185           -0.768533
# 4                 2.846858         -0.373185           -0.768533
# ...                    ...               ...                 ...
# 2171             -0.351264         -0.373185           -0.768533
# 2172             -0.351264         -0.373185           -0.768533
# 2173             -0.351264         -0.373185           -0.768533
# 2174             -0.351264         -0.373185           -0.768533
# 2175             -0.351264         -0.373185           -0.768533
#
#       County_Solano
# 0         -0.125988
# 1         -0.125988
# 2         -0.125988
# 3         -0.125988
# 4         -0.125988
# ...             ...
# 2171      -0.125988
# 2172      -0.125988
# 2173      -0.125988
# 2174      -0.125988
# 2175      -0.125988
#
# [2176 rows x 58 columns]

# %%
y
# Out:
# 0       0.377164
# 1      -1.087612
# 2      -1.329672
# 3      -0.491771
# 4       0.392681
#           ...
# 2171    1.888490
# 2172    0.271651
# 2173    1.094035
# 2174   -0.448324
# 2175    1.416782
# Name: Price per sqf ($), Length: 2176, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 20)

# %%
len(X_train)
# Out:
# 1740

# %%
len(X_test)
# Out:
# 436

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
#from sklearn.grid_search import GridSearchCV
from sklearn.metrics import accuracy_score
#from sklearn.learning_curve import validation_curve

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.inspection import permutation_importance

# %%
rf = RandomForestRegressor(n_estimators=200,max_depth=10)
rf.fit(X_train, y_train)
y_pred_rf= rf.predict((X_test))


def accuracy(y_pred_rf, y_test):
    return np.sum(y_pred_rf==y_test)/len(y_test)

acc=accuracy(y_test, y_pred_rf)
print(acc)
# Out:
# 0.0

# %%
# RF model evaluation using R squared method

r2 = r2_score(y_test, y_pred_rf)
print(r2)
# Out:
# 0.6802917234218003

# %%
#Mean Absolute Error

from sklearn.metrics import mean_absolute_error
y_pred_rf= rf.predict((X_test))
mae_rf = mean_absolute_error(y_test, y_pred_rf)

print(mae_rf)
# Out:
# 0.36074468198511433

# %%
from sklearn.metrics import mean_squared_error

mse_rf = mean_squared_error(y_test, y_pred_rf)

print(mse_rf)
# Out:
# 0.33213272313787395

# %%
rf.feature_importances_
# Out:
# array([9.94965060e-02, 1.96824590e-02, 1.65838793e-01, 1.76271921e-01,
#        1.30638472e-02, 1.21551003e-01, 7.51528857e-04, 4.57372758e-02,
#        4.43881991e-02, 5.15376477e-02, 1.41350721e-02, 5.33427500e-03,
#        6.64254921e-03, 2.85863678e-03, 3.67329307e-03, 9.45010959e-03,
#        7.41470381e-02, 1.19571788e-03, 5.43356727e-04, 4.90689296e-03,
#        7.67056786e-03, 2.92343475e-05, 1.77052949e-05, 1.13457206e-05,
#        2.60067849e-05, 2.39372896e-04, 8.18170671e-05, 1.61300108e-04,
#        6.05609964e-05, 1.85392107e-04, 5.66341336e-05, 8.40562808e-04,
#        7.77591864e-05, 4.34384949e-05, 5.32733736e-03, 1.15705225e-01,
#        1.39405097e-05, 2.07808117e-04, 2.18361141e-04, 7.76140441e-06,
#        7.74129374e-05, 1.55007054e-04, 1.35633969e-05, 2.19539957e-04,
#        8.33762713e-04, 2.83387563e-04, 4.45719147e-04, 6.85152169e-04,
#        8.96331368e-04, 7.03536738e-04, 9.08442877e-04, 4.13680347e-04,
#        4.57173610e-05, 1.65899682e-04, 2.24356772e-04, 1.39677736e-03,
#        3.35732971e-04, 7.72573048e-06])

# %%
plt.figure(figsize=(8,15))

plt.barh(X_train.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 58 artists>

# %%
plt.scatter(y_test, y_pred_rf)

# %% [markdown]
# # Updating model using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators':[200, 300, 400],
    'max_features':[10,12, 14]
}

grid_search = GridSearchCV(rf, param_grid, cv=5, scoring = 'neg_mean_squared_error', return_train_score=True)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(max_depth=10, n_estimators=200),
#              param_grid={'max_features': [10, 12, 14],
#                          'n_estimators': [200, 300, 400]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_rf = grid_search.best_estimator_

# %%
best_rf.score(X_test, y_test)
# Out:
# 0.6767353182344168

# %% [markdown]
# GridSearch does not provide better results than initial RandomForestRegressor.

# %% [markdown]
# # Removing additional data

# %%
train_data = scaled_df.drop(columns=['Living Area (sqf)', 'latitude', 'longitude', 'Median Price Growth (%) in the Area',])

# %%
X= train_data.drop("Price per sqf ($)", axis=1)

y = train_data['Price per sqf ($)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 20)

# %%
rf = RandomForestRegressor(n_estimators=500,max_depth=10)
rf.fit(X_train, y_train)
y_pred_rf= rf.predict((X_test))


def accuracy(y_pred_rf, y_test):
    return np.sum(y_pred_rf==y_test)/len(y_test)

acc=accuracy(y_test, y_pred_rf)
print(acc)
# Out:
# 0.0

# %%
r2_score(y_pred_rf, y_test)
# Out:
# 0.4493402548526826

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred_rf)
print(r2)
# Out:
# 0.631036233966097

# %%
from sklearn.metrics import mean_absolute_error
y_pred_rf= rf.predict((X_test))
mae_rf = mean_absolute_error(y_test, y_pred_rf)

print(mae_rf)
# Out:
# 0.41480529718935677

# %%
from sklearn.metrics import mean_squared_error

mse_rf = mean_squared_error(y_test, y_pred_rf)

print(mse_rf)
# Out:
# 0.3833023707225531

# %%
rf.feature_importances_
# Out:
# array([1.86111760e-01, 6.48378703e-02, 5.56439332e-02, 7.64943079e-02,
#        7.28450839e-02, 6.28277665e-02, 4.65775463e-02, 1.35077672e-02,
#        2.23996869e-02, 8.07011803e-03, 1.66436655e-02, 5.89128877e-03,
#        1.12258796e-01, 1.52936161e-03, 1.07929849e-03, 7.09689028e-03,
#        6.71445861e-02, 3.88166228e-04, 4.94501067e-05, 4.03440205e-04,
#        2.51433322e-04, 1.64122169e-04, 1.84835635e-04, 6.04374933e-04,
#        5.45785279e-04, 1.41497283e-05, 4.64077371e-04, 1.19354688e-03,
#        1.48793207e-04, 2.59543194e-04, 1.82032373e-02, 1.28996984e-01,
#        1.16635209e-05, 3.57870154e-04, 3.37198549e-04, 3.74446081e-04,
#        9.95262091e-04, 1.04110516e-03, 8.47108346e-05, 1.76814164e-03,
#        5.61029577e-03, 5.41157482e-04, 1.21260868e-03, 2.46789323e-03,
#        4.53678677e-04, 2.55114178e-03, 3.98241772e-03, 1.55035828e-03,
#        9.00631303e-05, 1.67153505e-05, 4.87225009e-04, 1.35316957e-03,
#        1.81845965e-03, 6.27504292e-05])

# %%
plt.figure(figsize=(20,15))

plt.barh(X_train.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 54 artists>

# %% [markdown]
# **After removing additional data significant features:** <br> Lot Area, <br> City_Palo_Alto, <br> Single Family Houses, <br> School Rating A-.

# %%
#plotting predicted and tested values
plt.scatter(y_test, y_pred_rf)

# %% [markdown]
# **Evaluating model on two types of data in price prediction:**<br> Price prediction in Counties; <br> Price prediction in Cities

# %% [markdown]
# # Price predictions in counties

# %%
counties_data = train_data.drop(columns=
['City_Benicia',
'City_Berkeley',
'City_Brentwood',
'City_Castro Valley',
'City_Dublin',
'City_Fremont',
'City_Lafayette',
'City_Larkspur',
'City_Livermore',
'City_Los Gatos',
'City_Martinez',
'City_Milpitas',
'City_Mountain View',
'City_Palo Alto',
'City_Piedmont',
'City_Pleasanton',
'City_Redwood City',
'City_San Francisco',
'City_San Jose',
'City_San Mateo',
'City_San Ramon',
'City_Santa Clara',
'City_Sunnyvale'])

# %%
X= counties_data.drop("Price per sqf ($)", axis=1)

y = counties_data['Price per sqf ($)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 20)

# %%
rf = RandomForestRegressor(n_estimators=500,max_depth=10)
rf.fit(X_train, y_train)
y_pred_rf= rf.predict((X_test))


def accuracy(y_pred_rf, y_test):
    return np.sum(y_pred_rf==y_test)/len(y_test)

acc=accuracy(y_test, y_pred_rf)
print(acc)
# Out:
# 0.0

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred_rf)
print(r2)
# Out:
# 0.6263536567802666

# %%
from sklearn.metrics import mean_absolute_error
y_pred_rf= rf.predict((X_test))
mae_rf = mean_absolute_error(y_test, y_pred_rf)

print(mae_rf)
# Out:
# 0.4182142275745018

# %%
from sklearn.metrics import mean_squared_error

mse_rf = mean_squared_error(y_test, y_pred_rf)

print(mse_rf)
# Out:
# 0.3881669213956812

# %%
rf.feature_importances_
# Out:
# array([2.05389873e-01, 6.75756580e-02, 6.09944999e-02, 8.13394965e-02,
#        7.63214341e-02, 7.01939452e-02, 9.50656470e-02, 2.13704677e-02,
#        4.78240930e-02, 1.97898476e-02, 2.49556002e-02, 4.90845943e-03,
#        1.13650180e-01, 1.80696674e-03, 2.22816374e-03, 1.54494044e-02,
#        6.66243249e-02, 8.32903764e-04, 7.41838882e-04, 1.34216605e-03,
#        2.69045325e-03, 6.40276046e-04, 2.27120300e-03, 4.05151389e-03,
#        1.36669027e-03, 1.34004605e-04, 4.52129034e-05, 6.76989907e-04,
#        5.91001189e-03, 3.74238802e-03, 6.62852870e-05])

# %%
plt.figure(figsize=(10,8))

plt.barh(X_train.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 31 artists>

# %%
plt.scatter(y_test, y_pred_rf)

# %% [markdown]
# Model is giving only slightly better results of r2 than calculating counties and cities together.

# %% [markdown]
# # Price predictions in cities

# %%
cities_data = train_data.drop(columns=
[
'County_Alameda', 
'County_Contra Costa',
'County_Marin',
'County_San Francisco', 
'County_San Mateo',
'County_Santa Clara', 
'County_Solano'])

# %%
X = cities_data.drop("Price per sqf ($)", axis=1)

y = cities_data['Price per sqf ($)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 20)

# %%
rf = RandomForestRegressor(n_estimators=200,max_depth=10)
rf.fit(X_train, y_train)
y_pred_rf= rf.predict((X_test))


def accuracy(y_pred_rf, y_test):
    return np.sum(y_pred_rf==y_test)/len(y_test)

acc=accuracy(y_test, y_pred_rf)
print(acc)
# Out:
# 0.0

# %%
r2 = r2_score(y_test, y_pred_rf)
print(r2)
# Out:
# 0.6338300142021711

# %%
rf.feature_importances_
# Out:
# array([1.78628662e-01, 6.24380228e-02, 5.79344404e-02, 7.06715926e-02,
#        8.01321692e-02, 6.33690424e-02, 4.78255937e-02, 1.42459256e-02,
#        1.95666253e-02, 8.54240205e-03, 1.51459849e-02, 5.25566556e-03,
#        1.10059938e-01, 1.62338871e-03, 1.24675136e-03, 6.38495743e-03,
#        7.19901146e-02, 7.35448465e-04, 9.70740041e-05, 2.98458278e-04,
#        3.61620358e-04, 1.36335465e-04, 1.96191549e-04, 6.00162981e-04,
#        5.78308999e-04, 2.28478322e-05, 4.53415973e-04, 1.69618929e-03,
#        1.67711496e-04, 1.46889111e-04, 1.93970818e-02, 1.38353944e-01,
#        1.38341745e-05, 3.80743038e-04, 5.66278099e-04, 4.02168390e-04,
#        1.07737078e-03, 8.92048702e-04, 9.50203710e-05, 1.11859665e-03,
#        6.07277242e-03, 5.26591807e-04, 1.24262882e-03, 2.70480334e-03,
#        5.06048945e-04, 2.25645610e-03, 3.84168256e-03])

# %%
plt.figure(figsize=(15,10))

plt.barh(X_train.columns, rf.feature_importances_)
# Out:
# <BarContainer object of 47 artists>

# %% [markdown]
# # Price prediction only for Palo Alto city

# %%
Palo_Alto_data = cities_data.drop(columns=
['City_Benicia',
'City_Alameda',
'City_Berkeley',
'City_Brentwood',
'City_Castro Valley',
'City_Dublin',
'City_Fremont',
'City_Lafayette',
'City_Larkspur',
'City_Livermore',
'City_Los Gatos',
'City_Martinez',
'City_Milpitas',
'City_Mountain View',
'City_Piedmont',
'City_Pleasanton',
'City_Redwood City',
'City_San Francisco',
'City_San Jose',
'City_San Mateo',
'City_San Ramon',
'City_Santa Clara',
'City_Sunnyvale'])

# %%
X_pa = Palo_Alto_data.drop("Price per sqf ($)", axis=1)

y_pa = Palo_Alto_data['Price per sqf ($)']

# %%
X_pa_train, X_pa_test, y_pa_train, y_pa_test = train_test_split(X_pa,y_pa,test_size = 0.2, random_state = 20)

# %%
rf_pa = RandomForestRegressor(n_estimators=200,max_depth=10)
rf_pa.fit(X_pa_train, y_pa_train)
y_pa_pred_rf= rf_pa.predict((X_pa_test))


def accuracy(y_pa_pred_rf, y_pa_test):
    return np.sum(y_pa_pred_rf==y_pa_test)/len(y_pa_test)

acc=accuracy(y_pa_test, y_pa_pred_rf)
print(acc)
# Out:
# 0.0

# %%
r2_pa = r2_score(y_pa_test, y_pa_pred_rf)
print(r2_pa)
# Out:
# 0.6286060172151626

# %%
rf_pa.feature_importances_
# Out:
# array([0.18379893, 0.06641308, 0.05920627, 0.07224425, 0.07952361,
#        0.062941  , 0.051445  , 0.01764259, 0.0282533 , 0.01206082,
#        0.02367813, 0.00755107, 0.10776035, 0.00165164, 0.00182672,
#        0.0118762 , 0.06324864, 0.13748186, 0.0008724 , 0.00113004,
#        0.00256559, 0.00069175, 0.00232374, 0.00381301])

# %%
plt.figure(figsize=(15,10))

plt.barh(X_pa_train.columns, rf_pa.feature_importances_)
# Out:
# <BarContainer object of 24 artists>

# %%
plt.scatter(y_pa_test, y_pa_pred_rf)

# %%
train_data.columns
# Out:
# Index(['Lot Area (sqf)', 'Number of Bedrooms', 'Number of Bathrooms',
#        'Price per sqf ($)', 'Monthly Payment (($)[Tax&Ins])',
#        'Minimum Qualifying Income ($)', 'Unemployment Rate (%)',
#        'City Population', 'Total Crimes per 1000', 'Violent Crimes per 1000',
#        'Property Crimes per 1000', 'Burglary Crimes per 1000',
#        'Property Type_CONDO', 'Property Type_SINGLE_FAMILY',
#        'Property Type_TOWNHOUSE', 'School Rating_A', 'School Rating_A+',
#        'School Rating_A-', 'City_Alameda', 'City_Benicia', 'City_Berkeley',
#        'City_Brentwood', 'City_Castro Valley', 'City_Dublin', 'City_Fremont',
#        'City_Lafayette', 'City_Larkspur', 'City_Livermore', 'City_Los Gatos',
#        'City_Martinez', 'City_Milpitas', 'City_Mountain View',
#        'City_Palo Alto', 'City_Piedmont', 'City_Pleasanton',
#        'City_Redwood City', 'City_San Francisco', 'City_San Jose',
#        'City_San Mateo', 'City_San Ramon', 'City_Santa Clara',
#        'City_Sunnyvale', 'Construction Type_BUILDER_PLAN',
#        'Construction Type_BUILDER_SPEC', 'Construction Type_False',
#        'Construction Type_NEW_CONSTRUCTION_TYPE_OTHER', 'Listing Type_False',
#        'Listing Type_True', 'County_Alameda', 'County_Contra Costa',
#        'County_Marin', 'County_San Francisco', 'County_San Mateo',
#        'County_Santa Clara', 'County_Solano'],
#       dtype='object')

# %%
test_data = train_data.drop(columns=[
       'Property Type_CONDO',
    'Property Type_TOWNHOUSE',
       'School Rating_A', 'School Rating_A+',
       'School Rating_A-', 'City_Alameda', 'City_Benicia', 'City_Berkeley',
       'City_Brentwood', 'City_Castro Valley', 'City_Dublin', 'City_Fremont',
       'City_Lafayette', 'City_Larkspur', 'City_Livermore', 'City_Los Gatos',
       'City_Martinez', 'City_Milpitas', 
       'City_Piedmont', 'City_Pleasanton',
       'City_Redwood City', 'City_San Francisco', 'City_San Jose',
       'City_San Mateo', 'City_San Ramon', 'City_Santa Clara',
       'Construction Type_BUILDER_PLAN',
       'Construction Type_BUILDER_SPEC', 'Construction Type_False',
       'Construction Type_NEW_CONSTRUCTION_TYPE_OTHER', 'Listing Type_False',
       'Listing Type_True', 'County_Alameda', 'County_San Mateo', 'County_Santa Clara','County_Contra Costa',
       'County_Marin', 'County_San Francisco', 
        'County_Solano'
])

# %%
X_f = test_data.drop("Price per sqf ($)", axis=1)

y_f = test_data['Price per sqf ($)']

# %%
X_f_train, X_f_test, y_f_train, y_f_test = train_test_split(X_f,y_f,test_size = 0.2, random_state = 20)

# %%
rf_f = RandomForestRegressor(n_estimators=200,max_depth=10)
rf_f.fit(X_f_train, y_f_train)
y_f_pred_rf= rf_f.predict((X_f_test))


def accuracy(y_f_pred_rf, y_f_test):
    return np.sum(y_f_pred_rf==y_f_test)/len(y_f_test)

acc=accuracy(y_f_test, y_f_pred_rf)
print(acc)
# Out:
# 0.0

# %%
r2_f = r2_score(y_f_test, y_f_pred_rf)
print(r2_f)
# Out:
# 0.6201850518588841

# %%
rf_f.feature_importances_
# Out:
# array([0.18772013, 0.06912652, 0.05678716, 0.08964259, 0.06262609,
#        0.06533595, 0.09018379, 0.01983314, 0.04762857, 0.01126824,
#        0.02665875, 0.11157654, 0.0196861 , 0.13616816, 0.00575828])

# %%
plt.figure(figsize=(15,10))

plt.barh(X_f_train.columns, rf_f.feature_importances_)
# Out:
# <BarContainer object of 15 artists>

# %%
plt.scatter(y_f_test, y_f_pred_rf)
